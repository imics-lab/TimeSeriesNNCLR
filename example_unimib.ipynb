# %% [markdown]
# # NNCLR example

# %% [markdown]
# ## Imports

# %%
import matplotlib.pyplot as plt
import tensorflow as tf
# import tensorflow_datasets as tfds
from tensorflow import keras
from tensorflow.keras import layers
import numpy as np

from data_loader import load_unimib_dataset
from augmentations import *
from encoder import encoder
from nnclr import NNCLR 

# %matplotlib inline

# %% [markdown]
# ## Load the data
#
# NNCLR takes in both the unlabeled and labeled data. The self-supervised encoder is trained on both the labeled and unlabeled data. The labeled data is used to train the classifier.

# %%
(batch_size, train_dataset, unlabeled_train_dataset, labeled_train_dataset, test_dataset, 
    x_train, y_train, x_validate, y_validate, x_test, y_test) = load_unimib_dataset()
# Out:
# Raw data     shape        object type              data type
# -----------  -----------  -----------------------  -----------
# adl_data:    (7579, 453)  <class 'numpy.ndarray'>  float64
# adl_labels:  (7579, 3)    <class 'numpy.ndarray'>  uint8
# adl_names:   (9, 1)       <class 'numpy.ndarray'>  object
# Reshaped data    shape           object type              data type
# ---------------  --------------  -----------------------  -----------
# adl_data:        (7579, 151, 4)  <class 'numpy.ndarray'>  float64
# adl_labels:      (7579, 3)       <class 'numpy.ndarray'>  uint8
# adl_names:       (9, 1)          <class 'numpy.ndarray'>  object
# x/y_train shape  (4601, 151, 4) (4601,)
# x/y_validation shape  (1454, 151, 4) (1454,)
# x/y_test shape   (1524, 151, 4) (1524,)
# x_train shape: (4601, 151, 4)
# y_train shape: (4601,)
# x_validate shape: (1454, 151, 4)
# y_validate shape: (1454,)
# x_test shape: (1524, 151, 4)
# y_test shape: (1524,)

# %%
print("x_train shape:", x_train.shape)
print("y_train shape:", y_train.shape)
print("x_validate shape:", x_validate.shape)
print("y_validate shape:", y_validate.shape)
print("x_test shape:", x_test.shape)
print("y_test shape:", y_test.shape)
# Out:
# x_train shape: (4601, 151, 4)
# y_train shape: (4601,)
# x_validate shape: (1454, 151, 4)
# y_validate shape: (1454,)
# x_test shape: (1524, 151, 4)
# y_test shape: (1524,)

# %% [markdown]
# ## Set configuration parameters

# %%
### Hyperparameters
try:
    AUTOTUNE = tf.data.AUTOTUNE     
except:
    AUTOTUNE = tf.data.experimental.AUTOTUNE

temperature = 0.1        # the temperature for the softmax function in the contrastive loss
queue_size = 1000        # the size of the queue for storing the feature vectors

width = 64                  # the size of the output embedding vector for each sequence
pretrain_num_epochs = 100   # the number of epochs to pretrain the model
finetune_num_epochs = 100    # The number of epochs to fine-tune the model.
BATCH_SIZE = 16             # the batch size for training
SHUFFLE_BUFFER_SIZE = 1000  # the buffer size for shuffling the dataset
k_size = 16                 # the size of the kernel for the 1D convolutional layer in the encoder
n_classes = np.unique(y_train).shape[0]  # the number of classes in the dataset

# %% [markdown]
# ## Pre-train NNCLR

# %% [markdown]
# ### Specify the encoder

# %%
input_shape = x_train[0].shape # Get the shape from the first element of the training set

# Create the encoder model
encoder_model = keras.Sequential(
		[
			keras.Input(shape=input_shape),
			layers.Conv1D(filters=100, kernel_size=10, activation='relu'),
			layers.Conv1D(filters=100, kernel_size=10, activation='relu'),
			layers.Dropout(0.5),
			layers.MaxPooling1D(pool_size=2),
			layers.Flatten(),
			layers.Dense(width, activation='relu')
   		],
        name="encoder_model",
    )
encoder_model.summary()
# Out:
# Model: "encoder_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_2 (Conv1D)           (None, 142, 100)          4100
#
#  conv1d_3 (Conv1D)           (None, 133, 100)          100100
#
#  dropout_1 (Dropout)         (None, 133, 100)          0
#
#  max_pooling1d_1 (MaxPoolin  (None, 66, 100)           0
#  g1D)
#
#  flatten_1 (Flatten)         (None, 6600)              0
#
#  dense_4 (Dense)             (None, 100)               660100
#
#  dense_5 (Dense)             (None, 64)                6464
#
# =================================================================
# Total params: 770764 (2.94 MB)
# Trainable params: 770764 (2.94 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### Perform self-supervised training

# %%
model = NNCLR(temperature=temperature, queue_size=queue_size, input_shape=input_shape, output_width=width, n_classes= n_classes, encoder=encoder_model)

model.compile(
    contrastive_optimizer=keras.optimizers.Adam(),
    probe_optimizer=keras.optimizers.Adam(),
    run_eagerly=None # True = run eagerly, False = run as graph, None = autodetect
)

model.build(input_shape=(None, input_shape[0], input_shape[1]))
model.summary()
# Out:
# Model: "nnclr_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  contrastive_augmenter (Seq  (None, None, 4)           0
#  uential)
#
#  classification_augmenter (  (None, None, 4)           0
#  Sequential)
#
#  encoder_model (Sequential)  (None, 64)                770764
#
#  projection_head (Sequentia  (None, 64)                8320
#  l)
#
#  linear_probe (Sequential)   (None, 9)                 585
#
# =================================================================
# Total params: 843675 (3.22 MB)
# Trainable params: 779669 (2.97 MB)
# Non-trainable params: 64006 (250.02 KB)
# _________________________________________________________________

# %%
pretrain_history = model.fit(
    train_dataset, epochs=pretrain_num_epochs, validation_data=test_dataset, 
    verbose=2 # 0 = silent, 1 = progress bar, 2 = one line per epoch, 3 = one line per batch
              # Due to a weird bug, the fit function crashes if verbose is set to 1.
)
# Out:
# Epoch 1/100
# 91/91 - 8s - c_loss: 2.4982 - c_acc: 0.1837 - r_acc: 0.1904 - p_loss: 4.0013 - p_acc: 0.1664 - val_p_loss: 3.8224 - val_p_acc: 0.2697 - 8s/epoch - 91ms/step
# Epoch 2/100
# 91/91 - 4s - c_loss: 1.9538 - c_acc: 0.3543 - r_acc: 0.3656 - p_loss: 5.2491 - p_acc: 0.2971 - val_p_loss: 5.0221 - val_p_acc: 0.2021 - 4s/epoch - 45ms/step
# Epoch 3/100
# 91/91 - 4s - c_loss: 2.1941 - c_acc: 0.4423 - r_acc: 0.4029 - p_loss: 6.4688 - p_acc: 0.2476 - val_p_loss: 6.5095 - val_p_acc: 0.2395 - 4s/epoch - 45ms/step
# Epoch 4/100
# 91/91 - 4s - c_loss: 2.3196 - c_acc: 0.4905 - r_acc: 0.4198 - p_loss: 6.1088 - p_acc: 0.1802 - val_p_loss: 5.1929 - val_p_acc: 0.2185 - 4s/epoch - 45ms/step
# Epoch 5/100
# 91/91 - 4s - c_loss: 1.7244 - c_acc: 0.5613 - r_acc: 0.4418 - p_loss: 7.0601 - p_acc: 0.2352 - val_p_loss: 5.0929 - val_p_acc: 0.2749 - 4s/epoch - 45ms/step
# Epoch 6/100
# 91/91 - 4s - c_loss: 1.7626 - c_acc: 0.6380 - r_acc: 0.4718 - p_loss: 7.5652 - p_acc: 0.1960 - val_p_loss: 6.0194 - val_p_acc: 0.2415 - 4s/epoch - 45ms/step
# Epoch 7/100
# 91/91 - 4s - c_loss: 1.3777 - c_acc: 0.6708 - r_acc: 0.5076 - p_loss: 7.5367 - p_acc: 0.2387 - val_p_loss: 5.2630 - val_p_acc: 0.3189 - 4s/epoch - 44ms/step
# Epoch 8/100
# 91/91 - 4s - c_loss: 1.4582 - c_acc: 0.6658 - r_acc: 0.5181 - p_loss: 5.2110 - p_acc: 0.2180 - val_p_loss: 4.3234 - val_p_acc: 0.3071 - 4s/epoch - 45ms/step
# Epoch 9/100
# 91/91 - 4s - c_loss: 1.1231 - c_acc: 0.7017 - r_acc: 0.5253 - p_loss: 7.0779 - p_acc: 0.2813 - val_p_loss: 6.4709 - val_p_acc: 0.3419 - 4s/epoch - 44ms/step
# Epoch 10/100
# 91/91 - 4s - c_loss: 1.2757 - c_acc: 0.7017 - r_acc: 0.5312 - p_loss: 8.2387 - p_acc: 0.2799 - val_p_loss: 10.0378 - val_p_acc: 0.4121 - 4s/epoch - 45ms/step
# Epoch 11/100
# 91/91 - 4s - c_loss: 1.5993 - c_acc: 0.7321 - r_acc: 0.5575 - p_loss: 7.0108 - p_acc: 0.2765 - val_p_loss: 7.9336 - val_p_acc: 0.4265 - 4s/epoch - 44ms/step
# Epoch 12/100
# 91/91 - 4s - c_loss: 1.3840 - c_acc: 0.7395 - r_acc: 0.5694 - p_loss: 5.9908 - p_acc: 0.3232 - val_p_loss: 7.3376 - val_p_acc: 0.3773 - 4s/epoch - 45ms/step
# Epoch 13/100
# 91/91 - 4s - c_loss: 1.0705 - c_acc: 0.7405 - r_acc: 0.5630 - p_loss: 6.1756 - p_acc: 0.2971 - val_p_loss: 7.2577 - val_p_acc: 0.4377 - 4s/epoch - 46ms/step
# Epoch 14/100
# 91/91 - 4s - c_loss: 1.1654 - c_acc: 0.7655 - r_acc: 0.5739 - p_loss: 5.6493 - p_acc: 0.3384 - val_p_loss: 6.3678 - val_p_acc: 0.4068 - 4s/epoch - 46ms/step
# Epoch 15/100
# 91/91 - 4s - c_loss: 1.2410 - c_acc: 0.7722 - r_acc: 0.5725 - p_loss: 3.8849 - p_acc: 0.3157 - val_p_loss: 6.4496 - val_p_acc: 0.4285 - 4s/epoch - 47ms/step
# Epoch 16/100
# 91/91 - 5s - c_loss: 1.4431 - c_acc: 0.7809 - r_acc: 0.5768 - p_loss: 4.9438 - p_acc: 0.3411 - val_p_loss: 5.8378 - val_p_acc: 0.3228 - 5s/epoch - 51ms/step
# Epoch 17/100
# 91/91 - 4s - c_loss: 1.6418 - c_acc: 0.7950 - r_acc: 0.5757 - p_loss: 6.3334 - p_acc: 0.3315 - val_p_loss: 6.4484 - val_p_acc: 0.4219 - 4s/epoch - 45ms/step
# Epoch 18/100
# 91/91 - 4s - c_loss: 1.0536 - c_acc: 0.7964 - r_acc: 0.5990 - p_loss: 4.2445 - p_acc: 0.3274 - val_p_loss: 4.3407 - val_p_acc: 0.4022 - 4s/epoch - 46ms/step
# Epoch 19/100
# 91/91 - 4s - c_loss: 1.3305 - c_acc: 0.8024 - r_acc: 0.6028 - p_loss: 5.3103 - p_acc: 0.2957 - val_p_loss: 4.7270 - val_p_acc: 0.4193 - 4s/epoch - 48ms/step
# Epoch 20/100
# 91/91 - 4s - c_loss: 1.1728 - c_acc: 0.8136 - r_acc: 0.5941 - p_loss: 5.4933 - p_acc: 0.3122 - val_p_loss: 6.2564 - val_p_acc: 0.4823 - 4s/epoch - 44ms/step
# Epoch 21/100
# 91/91 - 4s - c_loss: 0.9829 - c_acc: 0.8074 - r_acc: 0.6018 - p_loss: 5.5506 - p_acc: 0.3232 - val_p_loss: 6.8530 - val_p_acc: 0.4154 - 4s/epoch - 45ms/step
# Epoch 22/100
# 91/91 - 4s - c_loss: 1.3789 - c_acc: 0.8225 - r_acc: 0.6137 - p_loss: 3.3478 - p_acc: 0.3033 - val_p_loss: 3.6315 - val_p_acc: 0.4685 - 4s/epoch - 48ms/step
# Epoch 23/100
# 91/91 - 4s - c_loss: 1.2361 - c_acc: 0.8265 - r_acc: 0.6084 - p_loss: 4.6736 - p_acc: 0.3356 - val_p_loss: 6.4097 - val_p_acc: 0.3983 - 4s/epoch - 44ms/step
# Epoch 24/100
# 91/91 - 4s - c_loss: 1.0551 - c_acc: 0.8320 - r_acc: 0.6223 - p_loss: 4.4267 - p_acc: 0.3418 - val_p_loss: 5.6742 - val_p_acc: 0.4370 - 4s/epoch - 43ms/step
# Epoch 25/100
# 91/91 - 4s - c_loss: 1.1487 - c_acc: 0.8278 - r_acc: 0.6244 - p_loss: 3.1468 - p_acc: 0.3624 - val_p_loss: 5.9286 - val_p_acc: 0.4304 - 4s/epoch - 47ms/step
# Epoch 26/100
# 91/91 - 4s - c_loss: 1.0663 - c_acc: 0.8421 - r_acc: 0.6312 - p_loss: 3.9643 - p_acc: 0.3219 - val_p_loss: 6.1736 - val_p_acc: 0.4180 - 4s/epoch - 48ms/step
# Epoch 27/100
# 91/91 - 4s - c_loss: 1.0194 - c_acc: 0.8363 - r_acc: 0.6440 - p_loss: 4.4748 - p_acc: 0.3796 - val_p_loss: 6.8271 - val_p_acc: 0.4567 - 4s/epoch - 44ms/step
# Epoch 28/100
# 91/91 - 4s - c_loss: 1.0351 - c_acc: 0.8392 - r_acc: 0.6421 - p_loss: 2.9437 - p_acc: 0.3741 - val_p_loss: 4.2962 - val_p_acc: 0.4278 - 4s/epoch - 43ms/step
# Epoch 29/100
# 91/91 - 4s - c_loss: 0.9048 - c_acc: 0.8488 - r_acc: 0.6440 - p_loss: 3.4461 - p_acc: 0.3583 - val_p_loss: 6.4106 - val_p_acc: 0.5046 - 4s/epoch - 43ms/step
# Epoch 30/100
# 91/91 - 4s - c_loss: 0.9804 - c_acc: 0.8387 - r_acc: 0.6387 - p_loss: 3.2574 - p_acc: 0.3487 - val_p_loss: 5.5287 - val_p_acc: 0.4547 - 4s/epoch - 43ms/step
# Epoch 31/100
# 91/91 - 4s - c_loss: 1.2151 - c_acc: 0.8485 - r_acc: 0.6463 - p_loss: 3.5603 - p_acc: 0.3900 - val_p_loss: 5.5299 - val_p_acc: 0.4199 - 4s/epoch - 42ms/step
# Epoch 45/100
# 91/91 - 4s - c_loss: 0.7366 - c_acc: 0.8821 - r_acc: 0.6609 - p_loss: 2.7223 - p_acc: 0.3728 - val_p_loss: 4.2305 - val_p_acc: 0.4836 - 4s/epoch - 46ms/step
# Epoch 46/100
# 91/91 - 4s - c_loss: 1.0361 - c_acc: 0.8835 - r_acc: 0.6695 - p_loss: 2.1413 - p_acc: 0.4415 - val_p_loss: 2.6572 - val_p_acc: 0.4915 - 4s/epoch - 44ms/step
# Epoch 47/100
# 91/91 - 4s - c_loss: 0.7370 - c_acc: 0.8866 - r_acc: 0.6696 - p_loss: 2.4310 - p_acc: 0.3680 - val_p_loss: 5.4511 - val_p_acc: 0.4770 - 4s/epoch - 45ms/step
# Epoch 48/100
# 91/91 - 4s - c_loss: 0.6933 - c_acc: 0.8947 - r_acc: 0.6720 - p_loss: 2.1969 - p_acc: 0.3824 - val_p_loss: 3.7073 - val_p_acc: 0.4711 - 4s/epoch - 44ms/step
# Epoch 49/100
# 91/91 - 4s - c_loss: 0.8493 - c_acc: 0.8881 - r_acc: 0.6696 - p_loss: 2.4119 - p_acc: 0.3927 - val_p_loss: 3.4660 - val_p_acc: 0.5243 - 4s/epoch - 46ms/step
# Epoch 50/100
# 91/91 - 4s - c_loss: 0.7750 - c_acc: 0.8871 - r_acc: 0.6700 - p_loss: 1.8894 - p_acc: 0.4594 - val_p_loss: 4.8337 - val_p_acc: 0.5000 - 4s/epoch - 45ms/step
# Epoch 51/100
# 91/91 - 4s - c_loss: 0.6963 - c_acc: 0.8875 - r_acc: 0.6682 - p_loss: 2.6910 - p_acc: 0.4223 - val_p_loss: 4.8868 - val_p_acc: 0.4810 - 4s/epoch - 44ms/step
# Epoch 52/100
# 91/91 - 4s - c_loss: 0.9720 - c_acc: 0.8955 - r_acc: 0.6639 - p_loss: 1.5943 - p_acc: 0.4635 - val_p_loss: 4.5718 - val_p_acc: 0.4652 - 4s/epoch - 44ms/step
# Epoch 53/100
# 91/91 - 4s - c_loss: 0.9440 - c_acc: 0.8885 - r_acc: 0.6655 - p_loss: 2.2240 - p_acc: 0.4209 - val_p_loss: 3.8055 - val_p_acc: 0.4954 - 4s/epoch - 44ms/step
# Epoch 54/100
# 91/91 - 4s - c_loss: 0.7987 - c_acc: 0.8962 - r_acc: 0.6699 - p_loss: 1.6156 - p_acc: 0.3927 - val_p_loss: 4.2553 - val_p_acc: 0.4888 - 4s/epoch - 44ms/step
# Epoch 55/100
# 91/91 - 4s - c_loss: 0.8791 - c_acc: 0.8995 - r_acc: 0.6645 - p_loss: 2.7964 - p_acc: 0.4120 - val_p_loss: 3.2890 - val_p_acc: 0.4803 - 4s/epoch - 44ms/step
# Epoch 56/100
# 91/91 - 4s - c_loss: 0.9066 - c_acc: 0.9010 - r_acc: 0.6711 - p_loss: 2.1656 - p_acc: 0.4354 - val_p_loss: 5.3484 - val_p_acc: 0.4783 - 4s/epoch - 46ms/step
# Epoch 57/100
# 91/91 - 4s - c_loss: 0.8087 - c_acc: 0.8971 - r_acc: 0.6730 - p_loss: 2.0610 - p_acc: 0.4539 - val_p_loss: 4.9032 - val_p_acc: 0.4921 - 4s/epoch - 44ms/step
# Epoch 58/100
# 91/91 - 4s - c_loss: 0.8353 - c_acc: 0.9012 - r_acc: 0.6665 - p_loss: 2.0131 - p_acc: 0.4443 - val_p_loss: 6.1427 - val_p_acc: 0.4987 - 4s/epoch - 44ms/step
# Epoch 59/100
# 91/91 - 4s - c_loss: 0.6735 - c_acc: 0.8954 - r_acc: 0.6707 - p_loss: 1.8092 - p_acc: 0.4085 - val_p_loss: 5.2409 - val_p_acc: 0.5033 - 4s/epoch - 44ms/step
# Epoch 60/100
# 91/91 - 4s - c_loss: 0.8531 - c_acc: 0.9019 - r_acc: 0.6694 - p_loss: 1.2609 - p_acc: 0.4450 - val_p_loss: 5.4925 - val_p_acc: 0.5125 - 4s/epoch - 44ms/step
# Epoch 61/100
# 91/91 - 4s - c_loss: 0.8326 - c_acc: 0.8973 - r_acc: 0.6725 - p_loss: 1.2122 - p_acc: 0.4546 - val_p_loss: 4.4088 - val_p_acc: 0.4573 - 4s/epoch - 44ms/step
# Epoch 62/100
# 91/91 - 4s - c_loss: 0.9789 - c_acc: 0.9007 - r_acc: 0.6710 - p_loss: 2.5768 - p_acc: 0.4092 - val_p_loss: 3.8554 - val_p_acc: 0.5249 - 4s/epoch - 44ms/step
# Epoch 63/100
# 91/91 - 4s - c_loss: 0.7394 - c_acc: 0.9048 - r_acc: 0.6756 - p_loss: 2.4388 - p_acc: 0.4691 - val_p_loss: 2.7652 - val_p_acc: 0.4974 - 4s/epoch - 43ms/step
# Epoch 64/100
# 91/91 - 4s - c_loss: 0.8828 - c_acc: 0.9053 - r_acc: 0.6722 - p_loss: 1.5718 - p_acc: 0.4725 - val_p_loss: 3.2448 - val_p_acc: 0.5348 - 4s/epoch - 45ms/step
# Epoch 65/100
# 91/91 - 4s - c_loss: 0.7959 - c_acc: 0.9009 - r_acc: 0.6681 - p_loss: 1.8553 - p_acc: 0.4684 - val_p_loss: 4.6578 - val_p_acc: 0.5098 - 4s/epoch - 44ms/step
# Epoch 66/100
# 91/91 - 4s - c_loss: 0.8259 - c_acc: 0.9041 - r_acc: 0.6738 - p_loss: 1.1368 - p_acc: 0.4842 - val_p_loss: 3.9992 - val_p_acc: 0.5184 - 4s/epoch - 45ms/step
# Epoch 67/100
# 91/91 - 4s - c_loss: 0.8045 - c_acc: 0.9021 - r_acc: 0.6741 - p_loss: 1.4734 - p_acc: 0.5069 - val_p_loss: 3.7389 - val_p_acc: 0.5223 - 4s/epoch - 45ms/step
# Epoch 68/100
# 91/91 - 4s - c_loss: 0.8067 - c_acc: 0.9136 - r_acc: 0.6771 - p_loss: 1.3355 - p_acc: 0.4711 - val_p_loss: 2.8936 - val_p_acc: 0.5217 - 4s/epoch - 44ms/step
# Epoch 69/100
# 91/91 - 4s - c_loss: 0.8522 - c_acc: 0.9082 - r_acc: 0.6698 - p_loss: 1.3949 - p_acc: 0.4367 - val_p_loss: 3.4969 - val_p_acc: 0.5223 - 4s/epoch - 44ms/step
# Epoch 70/100
# 91/91 - 4s - c_loss: 0.8372 - c_acc: 0.9132 - r_acc: 0.6671 - p_loss: 1.4744 - p_acc: 0.4890 - val_p_loss: 1.8008 - val_p_acc: 0.5276 - 4s/epoch - 45ms/step
# Epoch 71/100
# 91/91 - 4s - c_loss: 1.0835 - c_acc: 0.9122 - r_acc: 0.6641 - p_loss: 1.6075 - p_acc: 0.4691 - val_p_loss: 4.5629 - val_p_acc: 0.5112 - 4s/epoch - 44ms/step
# Epoch 72/100
# 91/91 - 4s - c_loss: 0.6967 - c_acc: 0.9077 - r_acc: 0.6750 - p_loss: 1.1518 - p_acc: 0.4924 - val_p_loss: 2.6994 - val_p_acc: 0.4915 - 4s/epoch - 45ms/step
# Epoch 73/100
# 91/91 - 4s - c_loss: 0.8914 - c_acc: 0.9082 - r_acc: 0.6770 - p_loss: 1.8837 - p_acc: 0.4601 - val_p_loss: 3.8595 - val_p_acc: 0.5157 - 4s/epoch - 44ms/step
# Epoch 74/100
# 91/91 - 4s - c_loss: 0.7338 - c_acc: 0.9127 - r_acc: 0.6816 - p_loss: 1.1813 - p_acc: 0.4684 - val_p_loss: 2.8230 - val_p_acc: 0.4980 - 4s/epoch - 44ms/step
# Epoch 75/100
# 91/91 - 4s - c_loss: 0.8622 - c_acc: 0.9141 - r_acc: 0.6707 - p_loss: 1.2131 - p_acc: 0.4415 - val_p_loss: 3.2369 - val_p_acc: 0.4698 - 4s/epoch - 44ms/step
# Epoch 76/100
# 91/91 - 4s - c_loss: 0.7491 - c_acc: 0.9093 - r_acc: 0.6784 - p_loss: 1.4655 - p_acc: 0.5275 - val_p_loss: 1.9678 - val_p_acc: 0.5079 - 4s/epoch - 44ms/step
# Epoch 77/100
# 91/91 - 4s - c_loss: 0.8479 - c_acc: 0.9177 - r_acc: 0.6805 - p_loss: 1.7808 - p_acc: 0.4567 - val_p_loss: 5.2089 - val_p_acc: 0.4902 - 4s/epoch - 44ms/step
# Epoch 78/100
# 91/91 - 4s - c_loss: 0.9828 - c_acc: 0.9141 - r_acc: 0.6750 - p_loss: 2.7398 - p_acc: 0.5096 - val_p_loss: 5.4649 - val_p_acc: 0.4993 - 4s/epoch - 44ms/step
# Epoch 79/100
# 91/91 - 4s - c_loss: 0.6906 - c_acc: 0.9132 - r_acc: 0.6890 - p_loss: 2.0702 - p_acc: 0.4649 - val_p_loss: 5.9874 - val_p_acc: 0.4895 - 4s/epoch - 46ms/step
# Epoch 80/100
# 91/91 - 4s - c_loss: 0.8559 - c_acc: 0.9110 - r_acc: 0.6824 - p_loss: 1.3248 - p_acc: 0.4952 - val_p_loss: 3.4296 - val_p_acc: 0.5131 - 4s/epoch - 45ms/step
# Epoch 81/100
# 91/91 - 4s - c_loss: 0.5694 - c_acc: 0.9141 - r_acc: 0.6875 - p_loss: 2.4119 - p_acc: 0.4663 - val_p_loss: 2.7179 - val_p_acc: 0.5066 - 4s/epoch - 44ms/step
# Epoch 82/100
# 91/91 - 4s - c_loss: 0.7986 - c_acc: 0.9129 - r_acc: 0.6832 - p_loss: 2.9099 - p_acc: 0.4862 - val_p_loss: 6.2962 - val_p_acc: 0.5315 - 4s/epoch - 45ms/step
# Epoch 83/100
# 91/91 - 4s - c_loss: 0.8144 - c_acc: 0.9115 - r_acc: 0.6724 - p_loss: 2.5190 - p_acc: 0.4498 - val_p_loss: 5.3718 - val_p_acc: 0.5335 - 4s/epoch - 44ms/step
# Epoch 84/100
# 91/91 - 4s - c_loss: 0.7476 - c_acc: 0.9149 - r_acc: 0.6842 - p_loss: 2.6365 - p_acc: 0.5034 - val_p_loss: 6.3210 - val_p_acc: 0.5446 - 4s/epoch - 44ms/step
# Epoch 85/100
# 91/91 - 4s - c_loss: 0.6177 - c_acc: 0.9184 - r_acc: 0.6877 - p_loss: 3.3251 - p_acc: 0.5021 - val_p_loss: 6.9642 - val_p_acc: 0.5066 - 4s/epoch - 44ms/step
# Epoch 86/100
# 91/91 - 4s - c_loss: 0.8275 - c_acc: 0.9194 - r_acc: 0.6985 - p_loss: 2.3550 - p_acc: 0.5303 - val_p_loss: 5.7075 - val_p_acc: 0.4836 - 4s/epoch - 46ms/step
# Epoch 87/100
# 91/91 - 4s - c_loss: 0.6113 - c_acc: 0.9204 - r_acc: 0.6928 - p_loss: 4.2152 - p_acc: 0.4890 - val_p_loss: 8.3436 - val_p_acc: 0.5322 - 4s/epoch - 45ms/step
# Epoch 88/100
# 91/91 - 4s - c_loss: 0.5305 - c_acc: 0.9206 - r_acc: 0.6975 - p_loss: 2.3119 - p_acc: 0.5117 - val_p_loss: 5.8433 - val_p_acc: 0.5138 - 4s/epoch - 45ms/step
# Epoch 89/100
# 91/91 - 4s - c_loss: 1.0171 - c_acc: 0.9179 - r_acc: 0.6946 - p_loss: 1.6543 - p_acc: 0.5282 - val_p_loss: 5.2475 - val_p_acc: 0.5066 - 4s/epoch - 45ms/step
# Epoch 90/100
# 91/91 - 4s - c_loss: 0.8488 - c_acc: 0.9220 - r_acc: 0.6921 - p_loss: 2.4690 - p_acc: 0.5193 - val_p_loss: 3.8769 - val_p_acc: 0.5282 - 4s/epoch - 44ms/step
# Epoch 91/100
# 91/91 - 4s - c_loss: 0.7202 - c_acc: 0.9198 - r_acc: 0.6982 - p_loss: 1.4869 - p_acc: 0.4986 - val_p_loss: 4.6140 - val_p_acc: 0.5098 - 4s/epoch - 44ms/step
# Epoch 92/100
# 91/91 - 4s - c_loss: 0.6967 - c_acc: 0.9187 - r_acc: 0.6836 - p_loss: 1.7486 - p_acc: 0.5062 - val_p_loss: 2.4437 - val_p_acc: 0.5302 - 4s/epoch - 45ms/step
# Epoch 93/100
# 91/91 - 4s - c_loss: 0.6938 - c_acc: 0.9156 - r_acc: 0.6926 - p_loss: 2.3728 - p_acc: 0.4979 - val_p_loss: 3.5120 - val_p_acc: 0.4843 - 4s/epoch - 47ms/step
# Epoch 94/100
# 91/91 - 5s - c_loss: 0.6525 - c_acc: 0.9179 - r_acc: 0.6876 - p_loss: 1.1004 - p_acc: 0.5062 - val_p_loss: 3.0443 - val_p_acc: 0.4797 - 5s/epoch - 51ms/step
# Epoch 95/100
# 91/91 - 4s - c_loss: 0.7968 - c_acc: 0.9199 - r_acc: 0.6878 - p_loss: 2.0174 - p_acc: 0.4856 - val_p_loss: 3.4226 - val_p_acc: 0.5072 - 4s/epoch - 49ms/step
# Epoch 96/100
# 91/91 - 4s - c_loss: 0.7244 - c_acc: 0.9249 - r_acc: 0.6891 - p_loss: 1.2770 - p_acc: 0.4759 - val_p_loss: 1.6446 - val_p_acc: 0.5007 - 4s/epoch - 46ms/step
# Epoch 97/100
# 91/91 - 4s - c_loss: 0.6720 - c_acc: 0.9328 - r_acc: 0.6926 - p_loss: 3.0988 - p_acc: 0.4801 - val_p_loss: 5.9157 - val_p_acc: 0.4816 - 4s/epoch - 45ms/step
# Epoch 98/100
# 91/91 - 4s - c_loss: 0.9886 - c_acc: 0.9225 - r_acc: 0.6981 - p_loss: 2.6976 - p_acc: 0.4519 - val_p_loss: 3.6550 - val_p_acc: 0.5013 - 4s/epoch - 45ms/step
# Epoch 99/100
# 91/91 - 4s - c_loss: 0.6613 - c_acc: 0.9263 - r_acc: 0.6988 - p_loss: 2.4181 - p_acc: 0.5282 - val_p_loss: 4.0602 - val_p_acc: 0.5217 - 4s/epoch - 45ms/step
# Epoch 100/100
# 91/91 - 4s - c_loss: 0.7453 - c_acc: 0.9247 - r_acc: 0.6980 - p_loss: 1.6361 - p_acc: 0.4663 - val_p_loss: 4.0779 - val_p_acc: 0.5295 - 4s/epoch - 46ms/step

# %% [markdown]
# ### Plot the training loss and accuracy
#
# *Contrastive accuracy*: self-supervised metric, the ratio of cases in which the representation of an image is more similar to its differently augmented version's one, than to the representation of any other image in the current batch.
#
# *Correlation accuracy*: self-supervised metric, the ratio of cases in which the representation of an image is more similar to its differently augmented version's one, than to the representation of any other image in the queue.
#
# *Probe accuracy*: supervised metric, the ratio of cases in which the representation of an image is more similar to its label's one, than to the representation of any other label.

# %%
print(pretrain_history.history.keys())
# Out:
# dict_keys(['c_loss', 'c_acc', 'r_acc', 'p_loss', 'p_acc', 'val_p_loss', 'val_p_acc'])

# %%
# summarize history for loss
plt.figure(figsize=(15, 10))
# plt.plot(pretrain_history.history['c_loss'])
plt.plot(pretrain_history.history['p_loss'])
plt.plot(pretrain_history.history['val_p_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['probe_loss', 'validation_prob_loss'], loc='upper right')
plt.show()

# %%
# summarize history for accuracy
plt.figure(figsize=(15, 10))
plt.plot(pretrain_history.history['c_acc'])
plt.plot(pretrain_history.history['r_acc'])
plt.plot(pretrain_history.history['p_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['contrastive_accuracy', 'correlation_accuracy', 'probe_accuracy'], loc='upper left')
plt.show()

# %% [markdown]
# ## Plot the learned representations using UMAP
#
# Plot the representations of the labeled data in the representation space learned by the NNCLR encoder. Use UMAP to reduce the dimensionality to 2. The color of each point corresponds to its label.

# %%
import matplotlib.pyplot as plt
plt.rc('font', size=12)          # controls default text sizes
plt.rc('axes', titlesize=16)     # fontsize of the axes title
plt.rc('axes', labelsize=12)    # fontsize of the x and y labels
plt.rc('legend', fontsize=12)    # legend fontsize
plt.rc('figure', titlesize=16)  # fontsize of the figure title

# %%
# Plot the representations of the unlabeled data in the representation space learned by the NNCLR encoder. Use UMAP to reduce the dimensionality to 2. The color of each point corresponds to its label.

import umap.umap_ as umap
import numpy as np

# Get the representations of the unlabeled data.
unlabeled_feature_vectors = model.encoder(x_train, training=False)

# Reduce the dimensionality of the representations to 2.
reducer = umap.UMAP()
umap_embeddings = reducer.fit_transform(unlabeled_feature_vectors)

# Plot the representations.
plt.figure(figsize=(12, 10))
plt.scatter(umap_embeddings[:, 0], umap_embeddings[:, 1], c=y_train, s=5.0, cmap='Spectral')
# plt.gca().set_aspect('equal', 'datalim')
plt.colorbar(boundaries=np.arange(n_classes+1)-0.5).set_ticks(np.arange(n_classes))
plt.title('UMAP projection of the representations of the unlabeled data')
# Out:
# Text(0.5, 1.0, 'UMAP projection of the representations of the unlabeled data')

# %%
# Plot the representations of the labeled data in the representation space learned by the NNCLR encoder. Use UMAP to reduce the dimensionality to 2.

# Get the representations of the labeled data.
labeled_feature_vectors = model.encoder(x_validate, training=False)

# Reduce the dimensionality of the representations to 2.
# reducer = umap.UMAP()
# umap_embeddings = reducer.fit_transform(labeled_feature_vectors)
umap_embeddings = reducer.transform(labeled_feature_vectors)

# Plot the representations.
plt.figure(figsize=(12, 10))
plt.scatter(umap_embeddings[:, 0], umap_embeddings[:, 1], c=y_validate, s=5.0, cmap='Spectral')
# plt.gca().set_aspect('equal', 'datalim')
plt.colorbar(boundaries=np.arange(n_classes+1)-0.5).set_ticks(np.arange(n_classes))
plt.title('UMAP projection of the representations of the labeled data')
# Out:
# c:\Users\vangelis\miniconda3\envs\ml\Lib\site-packages\scipy\sparse\_index.py:143: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# Text(0.5, 1.0, 'UMAP projection of the representations of the labeled data')

# %%
# Plot the representations of the test data in the representation space learned by the NNCLR encoder. Use UMAP to reduce the dimensionality to 2. The color of each point corresponds to its label.

# Get the representations of the test data.
test_feature_vectors = model.encoder(x_test, training=False)

# Reduce the dimensionality of the representations to 2.
# reducer = umap.UMAP()
# umap_embeddings = reducer.fit_transform(test_feature_vectors)
umap_embeddings = reducer.transform(test_feature_vectors)

# Plot the representations.
plt.figure(figsize=(12, 10))
plt.scatter(umap_embeddings[:, 0], umap_embeddings[:, 1], c=y_test, s=5.0, cmap='Spectral')
# plt.gca().set_aspect('equal', 'datalim')
plt.colorbar(boundaries=np.arange(n_classes+1)-0.5).set_ticks(np.arange(n_classes))
plt.title('UMAP projection of the representations of the test data')
# Out:
# Text(0.5, 1.0, 'UMAP projection of the representations of the test data')

# %% [markdown]
# ## Fine tune the model
#
# Fine tune the NNCLR encoder on the labeled data. The classifier is trained on the labeled data.

# %%
finetuning_model = keras.Sequential(
    [
        layers.Input(shape=input_shape),
        augmenter("classification_augmenter", input_shape=input_shape),
        model.encoder,
        layers.Dense(n_classes),
    ],
    name="finetuning_model",
)
finetuning_model.compile(
    optimizer=keras.optimizers.Adam(),
    loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=[keras.metrics.SparseCategoricalAccuracy(name="acc")],
    run_eagerly=None # True = run eagerly, False = run as graph, None = autodetect
)

finetuning_history = finetuning_model.fit(
    labeled_train_dataset, epochs=finetune_num_epochs, validation_data=test_dataset
)
# Out:
# Epoch 1/100
# 91/91 [==============================] - 2s 20ms/step - loss: 0.0344 - acc: 0.9876 - val_loss: 1.2479 - val_acc: 0.7684
# Epoch 86/100
# 91/91 [==============================] - 2s 19ms/step - loss: 0.0264 - acc: 0.9931 - val_loss: 1.3720 - val_acc: 0.7605
# Epoch 87/100
# 91/91 [==============================] - 2s 21ms/step - loss: 0.0327 - acc: 0.9911 - val_loss: 1.5605 - val_acc: 0.7500
# Epoch 88/100
# 91/91 [==============================] - 2s 20ms/step - loss: 0.0434 - acc: 0.9849 - val_loss: 1.4824 - val_acc: 0.7566
# Epoch 89/100
# 91/91 [==============================] - 2s 22ms/step - loss: 0.0905 - acc: 0.9814 - val_loss: 1.3816 - val_acc: 0.7238
# Epoch 90/100
# 91/91 [==============================] - 2s 23ms/step - loss: 0.0964 - acc: 0.9697 - val_loss: 1.3355 - val_acc: 0.7467
# Epoch 91/100
# 91/91 [==============================] - 2s 25ms/step - loss: 0.0640 - acc: 0.9807 - val_loss: 1.2500 - val_acc: 0.7362
# Epoch 92/100
# 91/91 [==============================] - 2s 19ms/step - loss: 0.0465 - acc: 0.9842 - val_loss: 1.4947 - val_acc: 0.7441
# Epoch 93/100
# 91/91 [==============================] - 2s 20ms/step - loss: 0.0495 - acc: 0.9862 - val_loss: 1.3570 - val_acc: 0.7480
# Epoch 94/100
# 91/91 [==============================] - 2s 21ms/step - loss: 0.0314 - acc: 0.9890 - val_loss: 1.3672 - val_acc: 0.7500
# Epoch 95/100
# 91/91 [==============================] - 2s 22ms/step - loss: 0.0320 - acc: 0.9938 - val_loss: 1.5524 - val_acc: 0.7428
# Epoch 96/100
# 91/91 [==============================] - 2s 23ms/step - loss: 0.0235 - acc: 0.9911 - val_loss: 1.5232 - val_acc: 0.7513
# Epoch 97/100
# 91/91 [==============================] - 2s 21ms/step - loss: 0.0199 - acc: 0.9924 - val_loss: 1.6441 - val_acc: 0.7467
# Epoch 98/100
# 91/91 [==============================] - 2s 21ms/step - loss: 0.0477 - acc: 0.9897 - val_loss: 1.3437 - val_acc: 0.7559
# Epoch 99/100
# 91/91 [==============================] - 2s 22ms/step - loss: 0.0338 - acc: 0.9904 - val_loss: 1.4002 - val_acc: 0.7349
# Epoch 100/100
# 91/91 [==============================] - 2s 20ms/step - loss: 0.0500 - acc: 0.9862 - val_loss: 1.3726 - val_acc: 0.7329

# %% [markdown]
# ### Plot the fine-tuning loss and accuracy

# %%
# summarize history for loss

plt.plot(finetuning_history.history['loss'])
plt.plot(finetuning_history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train_loss', 'test_loss'], loc='upper right')
plt.show()

# %%
# summarize history for accuracy
plt.plot(finetuning_history.history['acc'])
plt.plot(finetuning_history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train_accuracy', 'test_accuracy'], loc='upper left')
plt.show()

# %% [markdown]
# ## Evaluate our fine tuned model on the test set

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
import pandas as pd
import seaborn as sns
import numpy as np

#### Show results
predictions = finetuning_model.predict(test_dataset, verbose=0, batch_size=32)
#must use values not one-hot encoding, use argmax to convert
y_pred = np.argmax(predictions, axis=-1) # axis=-1 means last axis
y_test = np.concatenate([y for x, y in test_dataset], axis=0)
print('Prediction accuracy: {0:.3f}'.format(accuracy_score(y_test, y_pred)))

t_names = np.unique(y_test).astype(str)

print(classification_report(y_test, y_pred, target_names=t_names))
cm = confusion_matrix(y_test, y_pred)
print(cm)
cm_df = pd.DataFrame(cm,
                     index = t_names, 
                     columns = t_names)
fig = plt.figure(figsize=(6.5,5))
sns.heatmap(cm_df, annot=True, fmt='d', cmap='cubehelix_r')
plt.title('1D CNN using e4_Nov2019'+'\nAccuracy:{0:.3f}'.format(accuracy_score(y_test, y_pred)))
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.tight_layout() # keeps labels from being cutoff when saving as pdf
plt.show()
# Out:
# Prediction accuracy: 0.729
#               precision    recall  f1-score   support
#
#            0       0.62      0.47      0.53        34
#            1       0.47      0.60      0.53        47
#            2       0.77      0.42      0.54       344
#            3       0.98      0.96      0.97       413
#            4       0.57      0.76      0.65       184
#            5       0.84      0.78      0.81       146
#            6       0.60      0.85      0.70       256
#            7       0.65      0.54      0.59        68
#            8       0.40      0.59      0.48        32
#
#     accuracy                           0.73      1524
#    macro avg       0.66      0.66      0.65      1524
# weighted avg       0.75      0.73      0.72      1524
#
# [[ 16  17   0   0   0   0   0   1   0]
#  [  7  28   0   0   0   0   0   6   6]
#  [  0   0 145   4  94   5  93   1   2]
#  [  0   2   4 395   0   2  10   0   0]
#  [  0   1  16   0 139   4  23   0   1]
#  [  0   0   8   2   3 114  19   0   0]
#  [  2   0  16   2   7  11 218   0   0]
#  [  1  10   0   0   0   0   1  37  19]
#  [  0   1   0   0   0   0   0  12  19]]

# %% [markdown]
# ## Evaluate the learned representations using a KNN classifier

# %%
from sklearn.neighbors import KNeighborsClassifier

# Convert train dataset to feature vectors using the self-supervised encoder
train_feature_vectors = model.encoder(x_train, training=False)

knn = KNeighborsClassifier(n_neighbors=3)
knn_model = knn.fit(train_feature_vectors, y_train)

# Predict test set with the knn model
test_feature_vectors = model.encoder(x_test, training=False)
y_pred = knn_model.predict(test_feature_vectors)

print('Prediction accuracy: {0:.3f}'.format(accuracy_score(y_test, y_pred)))
print(classification_report(y_test, y_pred, target_names=t_names))
cm = confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# Prediction accuracy: 0.484
#               precision    recall  f1-score   support
#
#            0       0.34      0.62      0.44        34
#            1       0.04      0.38      0.07        47
#            2       0.46      0.25      0.32       344
#            3       0.85      0.83      0.84       413
#            4       0.39      0.12      0.19       184
#            5       0.98      0.80      0.88       146
#            6       0.55      0.41      0.47       256
#            7       0.52      0.24      0.32        68
#            8       0.45      0.31      0.37        32
#
#     accuracy                           0.48      1524
#    macro avg       0.51      0.44      0.43      1524
# weighted avg       0.61      0.48      0.52      1524
#
# [[ 21   3   0   0   0   0   9   1   0]
#  [ 12  18   2   0   5   0   1   6   3]
#  [  0 222  86  11   3   0  21   1   0]
#  [  1  21  24 342   4   0  21   0   0]
#  [  5 104  33   9  23   0  10   0   0]
#  [  0   0   3  11   5 117  10   0   0]
#  [  0  70  40  26  14   2 104   0   0]
#  [ 17  12   0   3   3   0   8  16   9]
#  [  5   2   0   0   2   0   6   7  10]]
