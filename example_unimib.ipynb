# %% [markdown]
# # NNCLR example for the [UniMiB SHAR dataset](http://www.sal.disco.unimib.it/technologies/unimib-shar/)

# %% [markdown]
# ## Imports

# %%
import matplotlib.pyplot as plt
from tensorflow import keras
from tensorflow.keras import layers
import numpy as np

from data_loader import load_unimib_dataset
from augmentations import augmenter
# from encoder import encoder
from nnclr import NNCLR 

# %matplotlib inline

# %% [markdown]
# ## Load the data
#
# NNCLR takes in both the unlabeled and labeled data. The self-supervised encoder is trained on both the labeled and unlabeled data. The labeled data is used to train the classifier.

# %%
(batch_size, train_dataset, unlabeled_train_dataset, labeled_train_dataset, test_dataset, 
    x_train, y_train, x_validate, y_validate, x_test, y_test) = load_unimib_dataset()

n_classes = np.unique(y_train).shape[0]  # the number of classes in the dataset
# Out:
# Raw data     shape        object type              data type
# -----------  -----------  -----------------------  -----------
# adl_data:    (7579, 453)  <class 'numpy.ndarray'>  float64
# adl_labels:  (7579, 3)    <class 'numpy.ndarray'>  uint8
# adl_names:   (9, 1)       <class 'numpy.ndarray'>  object
# Reshaped data    shape           object type              data type
# ---------------  --------------  -----------------------  -----------
# adl_data:        (7579, 151, 4)  <class 'numpy.ndarray'>  float64
# adl_labels:      (7579, 3)       <class 'numpy.ndarray'>  uint8
# adl_names:       (9, 1)          <class 'numpy.ndarray'>  object
# x/y_train shape  (4601, 151, 4) (4601,)
# x/y_validation shape  (1454, 151, 4) (1454,)
# x/y_test shape   (1524, 151, 4) (1524,)
# x_train shape: (4601, 151, 4)
# y_train shape: (4601,)
# x_validate shape: (1454, 151, 4)
# y_validate shape: (1454,)
# x_test shape: (1524, 151, 4)
# y_test shape: (1524,)

# %%
print("x_train shape:", x_train.shape)
print("y_train shape:", y_train.shape)
print("x_validate shape:", x_validate.shape)
print("y_validate shape:", y_validate.shape)
print("x_test shape:", x_test.shape)
print("y_test shape:", y_test.shape)
# Out:
# x_train shape: (4601, 151, 4)
# y_train shape: (4601,)
# x_validate shape: (1454, 151, 4)
# y_validate shape: (1454,)
# x_test shape: (1524, 151, 4)
# y_test shape: (1524,)

# %% [markdown]
# ## Set configuration parameters

# %%
temperature = 0.1        # the temperature for the softmax function in the contrastive loss
queue_size = 5000        # the size of the queue for storing the feature vectors of the neighbors

width = 64                  # the size of the output embedding vector for each sequence
pretrain_num_epochs = 100   # the number of epochs to pretrain the model
finetune_num_epochs = 100    # The number of epochs to fine-tune the model.

# %% [markdown]
# ## Pre-train NNCLR

# %% [markdown]
# ### Specify the encoder architecture

# %%
input_shape = x_train[0].shape # Get the shape from the first element of the training set

# Create the encoder model
encoder_model = keras.Sequential(
		[
			keras.Input(shape=input_shape),
			layers.Conv1D(filters=100, kernel_size=10, activation='relu'),
			layers.Conv1D(filters=100, kernel_size=10, activation='relu'),
			layers.Dropout(0.5),
			layers.MaxPooling1D(pool_size=2),
			layers.Flatten(),
			layers.Dense(width, activation='relu')
   		],
        name="encoder_model",
    )
encoder_model.summary()
# Out:
# Model: "encoder_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 142, 100)          4100
#
#  conv1d_1 (Conv1D)           (None, 133, 100)          100100
#
#  dropout (Dropout)           (None, 133, 100)          0
#
#  max_pooling1d (MaxPooling1  (None, 66, 100)           0
#  D)
#
#  flatten (Flatten)           (None, 6600)              0
#
#  dense (Dense)               (None, 64)                422464
#
# =================================================================
# Total params: 526664 (2.01 MB)
# Trainable params: 526664 (2.01 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### Perform self-supervised training

# %%
model = NNCLR(temperature=temperature, queue_size=queue_size, input_shape=input_shape, output_width=width, n_classes= n_classes, encoder=encoder_model)

model.compile(
    contrastive_optimizer=keras.optimizers.Adam(),
    probe_optimizer=keras.optimizers.Adam(),
    run_eagerly=None # True = run eagerly, False = run as graph, None = autodetect
)

model.build(input_shape=(None, input_shape[0], input_shape[1]))
model.summary()
# Out:
# Model: "nnclr"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  contrastive_augmenter (Seq  (None, None, 4)           0
#  uential)
#
#  classification_augmenter (  (None, None, 4)           0
#  Sequential)
#
#  encoder_model (Sequential)  (None, 64)                526664
#
#  projection_head (Sequentia  (None, 64)                8320
#  l)
#
#  linear_probe (Sequential)   (None, 9)                 585
#
# =================================================================
# Total params: 855575 (3.26 MB)
# Trainable params: 535569 (2.04 MB)
# Non-trainable params: 320006 (1.22 MB)
# _________________________________________________________________

# %%
pretrain_history = model.fit(
    train_dataset, epochs=pretrain_num_epochs, validation_data=test_dataset, 
    verbose=2 # 0 = silent, 1 = progress bar, 2 = one line per epoch, 3 = one line per batch
              # Due to a weird bug, the fit function crashes if verbose is set to 1.
)
# Out:
# Epoch 1/100
# 46/46 - 8s - c_loss: 3.2010 - c_acc: 0.1111 - r_acc: 0.1678 - p_loss: 5.1792 - p_acc: 0.1100 - val_p_loss: 4.9992 - val_p_acc: 0.2087 - 8s/epoch - 174ms/step
# Epoch 2/100
# 46/46 - 4s - c_loss: 2.1658 - c_acc: 0.2946 - r_acc: 0.4292 - p_loss: 4.2525 - p_acc: 0.1609 - val_p_loss: 3.9603 - val_p_acc: 0.2402 - 4s/epoch - 77ms/step
# Epoch 3/100
# 46/46 - 4s - c_loss: 2.2309 - c_acc: 0.3730 - r_acc: 0.4900 - p_loss: 3.6362 - p_acc: 0.1197 - val_p_loss: 3.3441 - val_p_acc: 0.1772 - 4s/epoch - 79ms/step
# Epoch 4/100
# 46/46 - 4s - c_loss: 1.6351 - c_acc: 0.4354 - r_acc: 0.4973 - p_loss: 5.4839 - p_acc: 0.1252 - val_p_loss: 5.6845 - val_p_acc: 0.1745 - 4s/epoch - 78ms/step
# Epoch 5/100
# 46/46 - 4s - c_loss: 1.7946 - c_acc: 0.4612 - r_acc: 0.4762 - p_loss: 6.9790 - p_acc: 0.1155 - val_p_loss: 7.3976 - val_p_acc: 0.2100 - 4s/epoch - 85ms/step
# Epoch 6/100
# 46/46 - 4s - c_loss: 1.6343 - c_acc: 0.5232 - r_acc: 0.4866 - p_loss: 6.3135 - p_acc: 0.1802 - val_p_loss: 6.8826 - val_p_acc: 0.2461 - 4s/epoch - 78ms/step
# Epoch 7/100
# 46/46 - 4s - c_loss: 1.3741 - c_acc: 0.5921 - r_acc: 0.4890 - p_loss: 5.2312 - p_acc: 0.1506 - val_p_loss: 5.8188 - val_p_acc: 0.2310 - 4s/epoch - 76ms/step
# Epoch 8/100
# 46/46 - 4s - c_loss: 1.0732 - c_acc: 0.6347 - r_acc: 0.5071 - p_loss: 5.2336 - p_acc: 0.1582 - val_p_loss: 5.3339 - val_p_acc: 0.2526 - 4s/epoch - 80ms/step
# Epoch 9/100
# 46/46 - 4s - c_loss: 0.9877 - c_acc: 0.6564 - r_acc: 0.5015 - p_loss: 4.3934 - p_acc: 0.1582 - val_p_loss: 5.1986 - val_p_acc: 0.2717 - 4s/epoch - 77ms/step
# Epoch 10/100
# 46/46 - 4s - c_loss: 1.2324 - c_acc: 0.6625 - r_acc: 0.5093 - p_loss: 6.1853 - p_acc: 0.1664 - val_p_loss: 6.0270 - val_p_acc: 0.3058 - 4s/epoch - 77ms/step
# Epoch 11/100
# 46/46 - 4s - c_loss: 1.1653 - c_acc: 0.6832 - r_acc: 0.5226 - p_loss: 4.5657 - p_acc: 0.2084 - val_p_loss: 4.5213 - val_p_acc: 0.2769 - 4s/epoch - 82ms/step
# Epoch 12/100
# 46/46 - 4s - c_loss: 0.9384 - c_acc: 0.6981 - r_acc: 0.5233 - p_loss: 4.7851 - p_acc: 0.2256 - val_p_loss: 4.0072 - val_p_acc: 0.3241 - 4s/epoch - 79ms/step
# Epoch 13/100
# 46/46 - 4s - c_loss: 1.2151 - c_acc: 0.7042 - r_acc: 0.5277 - p_loss: 4.5061 - p_acc: 0.2682 - val_p_loss: 5.5765 - val_p_acc: 0.3346 - 4s/epoch - 77ms/step
# Epoch 14/100
# 46/46 - 3s - c_loss: 1.0683 - c_acc: 0.7160 - r_acc: 0.5256 - p_loss: 3.5589 - p_acc: 0.2469 - val_p_loss: 4.5536 - val_p_acc: 0.3609 - 3s/epoch - 75ms/step
# Epoch 15/100
# 46/46 - 3s - c_loss: 1.0807 - c_acc: 0.7307 - r_acc: 0.5197 - p_loss: 5.0639 - p_acc: 0.2703 - val_p_loss: 5.7044 - val_p_acc: 0.3314 - 3s/epoch - 76ms/step
# Epoch 16/100
# 46/46 - 4s - c_loss: 1.0206 - c_acc: 0.7521 - r_acc: 0.5255 - p_loss: 4.4826 - p_acc: 0.2215 - val_p_loss: 5.5270 - val_p_acc: 0.3681 - 4s/epoch - 80ms/step
# Epoch 17/100
# 46/46 - 4s - c_loss: 1.0687 - c_acc: 0.7493 - r_acc: 0.5312 - p_loss: 3.8208 - p_acc: 0.2613 - val_p_loss: 5.1222 - val_p_acc: 0.3839 - 4s/epoch - 78ms/step
# Epoch 18/100
# 46/46 - 4s - c_loss: 1.0640 - c_acc: 0.7806 - r_acc: 0.5260 - p_loss: 3.3317 - p_acc: 0.2565 - val_p_loss: 6.1521 - val_p_acc: 0.3773 - 4s/epoch - 77ms/step
# Epoch 19/100
# 46/46 - 3s - c_loss: 0.9029 - c_acc: 0.7941 - r_acc: 0.5279 - p_loss: 3.0973 - p_acc: 0.2717 - val_p_loss: 5.6636 - val_p_acc: 0.3589 - 3s/epoch - 75ms/step
# Epoch 20/100
# 46/46 - 3s - c_loss: 0.9283 - c_acc: 0.7869 - r_acc: 0.5273 - p_loss: 4.4646 - p_acc: 0.2710 - val_p_loss: 7.1521 - val_p_acc: 0.3799 - 3s/epoch - 74ms/step
# Epoch 21/100
# 46/46 - 4s - c_loss: 0.8436 - c_acc: 0.7934 - r_acc: 0.5353 - p_loss: 3.2516 - p_acc: 0.2937 - val_p_loss: 7.4755 - val_p_acc: 0.3937 - 4s/epoch - 77ms/step
# Epoch 22/100
# 46/46 - 3s - c_loss: 0.7719 - c_acc: 0.8059 - r_acc: 0.5341 - p_loss: 2.5350 - p_acc: 0.2675 - val_p_loss: 6.2470 - val_p_acc: 0.3661 - 3s/epoch - 75ms/step
# Epoch 23/100
# 46/46 - 3s - c_loss: 0.8234 - c_acc: 0.7972 - r_acc: 0.5391 - p_loss: 3.3109 - p_acc: 0.2531 - val_p_loss: 6.5129 - val_p_acc: 0.3740 - 3s/epoch - 76ms/step
# Epoch 24/100
# 46/46 - 3s - c_loss: 0.8421 - c_acc: 0.8028 - r_acc: 0.5333 - p_loss: 3.8962 - p_acc: 0.2840 - val_p_loss: 6.9551 - val_p_acc: 0.3917 - 3s/epoch - 74ms/step
# Epoch 25/100
# 46/46 - 4s - c_loss: 0.7349 - c_acc: 0.8151 - r_acc: 0.5355 - p_loss: 3.2401 - p_acc: 0.3054 - val_p_loss: 7.3162 - val_p_acc: 0.3615 - 4s/epoch - 77ms/step
# Epoch 26/100
# 46/46 - 4s - c_loss: 0.9362 - c_acc: 0.8250 - r_acc: 0.5358 - p_loss: 3.3997 - p_acc: 0.3487 - val_p_loss: 7.4013 - val_p_acc: 0.3681 - 4s/epoch - 76ms/step
# Epoch 27/100
# 46/46 - 4s - c_loss: 0.7441 - c_acc: 0.8266 - r_acc: 0.5392 - p_loss: 3.4813 - p_acc: 0.2834 - val_p_loss: 6.1328 - val_p_acc: 0.4068 - 4s/epoch - 76ms/step
# Epoch 28/100
# 46/46 - 4s - c_loss: 0.9087 - c_acc: 0.8240 - r_acc: 0.5367 - p_loss: 2.8636 - p_acc: 0.3061 - val_p_loss: 6.4346 - val_p_acc: 0.3911 - 4s/epoch - 77ms/step
# Epoch 29/100
# 46/46 - 4s - c_loss: 0.8210 - c_acc: 0.8233 - r_acc: 0.5355 - p_loss: 3.5189 - p_acc: 0.3336 - val_p_loss: 7.0447 - val_p_acc: 0.4042 - 4s/epoch - 78ms/step
# Epoch 30/100
# 46/46 - 4s - c_loss: 0.6933 - c_acc: 0.8300 - r_acc: 0.5387 - p_loss: 4.3823 - p_acc: 0.3521 - val_p_loss: 7.0686 - val_p_acc: 0.4239 - 4s/epoch - 77ms/step
# Epoch 31/100
# 46/46 - 4s - c_loss: 0.7667 - c_acc: 0.8380 - r_acc: 0.5419 - p_loss: 3.2332 - p_acc: 0.2978 - val_p_loss: 6.6409 - val_p_acc: 0.4285 - 4s/epoch - 77ms/step
# Epoch 32/100
# 46/46 - 4s - c_loss: 0.7376 - c_acc: 0.8428 - r_acc: 0.5418 - p_loss: 4.1445 - p_acc: 0.3576 - val_p_loss: 6.9928 - val_p_acc: 0.4114 - 4s/epoch - 77ms/step
# Epoch 33/100
# 46/46 - 4s - c_loss: 0.7799 - c_acc: 0.8486 - r_acc: 0.5419 - p_loss: 3.8753 - p_acc: 0.3226 - val_p_loss: 6.4845 - val_p_acc: 0.4101 - 4s/epoch - 78ms/step
# Epoch 34/100
# 46/46 - 4s - c_loss: 0.8357 - c_acc: 0.8399 - r_acc: 0.5435 - p_loss: 3.8897 - p_acc: 0.3177 - val_p_loss: 6.6596 - val_p_acc: 0.4160 - 4s/epoch - 76ms/step
# Epoch 35/100
# 46/46 - 3s - c_loss: 0.7465 - c_acc: 0.8513 - r_acc: 0.5419 - p_loss: 3.2940 - p_acc: 0.3769 - val_p_loss: 6.5022 - val_p_acc: 0.4291 - 3s/epoch - 75ms/step
# Epoch 36/100
# 46/46 - 4s - c_loss: 0.6959 - c_acc: 0.8556 - r_acc: 0.5409 - p_loss: 2.8933 - p_acc: 0.4037 - val_p_loss: 5.7126 - val_p_acc: 0.4285 - 4s/epoch - 78ms/step
# Epoch 37/100
# 46/46 - 4s - c_loss: 0.6843 - c_acc: 0.8609 - r_acc: 0.5419 - p_loss: 3.5420 - p_acc: 0.3459 - val_p_loss: 5.4251 - val_p_acc: 0.4259 - 4s/epoch - 76ms/step
# Epoch 38/100
# 46/46 - 3s - c_loss: 0.7256 - c_acc: 0.8669 - r_acc: 0.5416 - p_loss: 2.2368 - p_acc: 0.3514 - val_p_loss: 4.6253 - val_p_acc: 0.4304 - 3s/epoch - 74ms/step
# Epoch 39/100
# 46/46 - 3s - c_loss: 0.5318 - c_acc: 0.8638 - r_acc: 0.5416 - p_loss: 2.1564 - p_acc: 0.4065 - val_p_loss: 5.4926 - val_p_acc: 0.4423 - 3s/epoch - 76ms/step
# Epoch 40/100
# 46/46 - 3s - c_loss: 0.7202 - c_acc: 0.8686 - r_acc: 0.5433 - p_loss: 2.7524 - p_acc: 0.4017 - val_p_loss: 5.9423 - val_p_acc: 0.4245 - 3s/epoch - 76ms/step
# Epoch 41/100
# 46/46 - 4s - c_loss: 0.7047 - c_acc: 0.8638 - r_acc: 0.5394 - p_loss: 2.9017 - p_acc: 0.4195 - val_p_loss: 4.9138 - val_p_acc: 0.4541 - 4s/epoch - 77ms/step
# Epoch 42/100
# 46/46 - 4s - c_loss: 0.6302 - c_acc: 0.8662 - r_acc: 0.5414 - p_loss: 2.3843 - p_acc: 0.3989 - val_p_loss: 5.3081 - val_p_acc: 0.4442 - 4s/epoch - 82ms/step
# Epoch 43/100
# 46/46 - 4s - c_loss: 0.6796 - c_acc: 0.8795 - r_acc: 0.5406 - p_loss: 2.0476 - p_acc: 0.3920 - val_p_loss: 5.0813 - val_p_acc: 0.4672 - 4s/epoch - 83ms/step
# Epoch 44/100
# 46/46 - 4s - c_loss: 0.5965 - c_acc: 0.8770 - r_acc: 0.5413 - p_loss: 1.9162 - p_acc: 0.4257 - val_p_loss: 5.0494 - val_p_acc: 0.4560 - 4s/epoch - 87ms/step
# Epoch 81/100
# 46/46 - 4s - c_loss: 0.5343 - c_acc: 0.9132 - r_acc: 0.5447 - p_loss: 0.9903 - p_acc: 0.4622 - val_p_loss: 3.8535 - val_p_acc: 0.5446 - 4s/epoch - 81ms/step
# Epoch 82/100
# 46/46 - 4s - c_loss: 0.5578 - c_acc: 0.9224 - r_acc: 0.5459 - p_loss: 1.3054 - p_acc: 0.4931 - val_p_loss: 4.1106 - val_p_acc: 0.5289 - 4s/epoch - 82ms/step
# Epoch 83/100
# 46/46 - 4s - c_loss: 0.4150 - c_acc: 0.9207 - r_acc: 0.5448 - p_loss: 1.2521 - p_acc: 0.5076 - val_p_loss: 3.7085 - val_p_acc: 0.5354 - 4s/epoch - 81ms/step
# Epoch 84/100
# 46/46 - 3s - c_loss: 0.5988 - c_acc: 0.9190 - r_acc: 0.5450 - p_loss: 1.3393 - p_acc: 0.4924 - val_p_loss: 3.8273 - val_p_acc: 0.5348 - 3s/epoch - 74ms/step
# Epoch 85/100
# 46/46 - 3s - c_loss: 0.6173 - c_acc: 0.9140 - r_acc: 0.5445 - p_loss: 0.9591 - p_acc: 0.4938 - val_p_loss: 3.6463 - val_p_acc: 0.5394 - 3s/epoch - 76ms/step
# Epoch 86/100
# 46/46 - 4s - c_loss: 0.4906 - c_acc: 0.9222 - r_acc: 0.5481 - p_loss: 0.9817 - p_acc: 0.5179 - val_p_loss: 3.9523 - val_p_acc: 0.5367 - 4s/epoch - 80ms/step
# Epoch 87/100
# 46/46 - 4s - c_loss: 0.5525 - c_acc: 0.9289 - r_acc: 0.5452 - p_loss: 0.8374 - p_acc: 0.5069 - val_p_loss: 3.2128 - val_p_acc: 0.5289 - 4s/epoch - 84ms/step
# Epoch 88/100
# 46/46 - 4s - c_loss: 0.3413 - c_acc: 0.9240 - r_acc: 0.5453 - p_loss: 1.1658 - p_acc: 0.5007 - val_p_loss: 3.4636 - val_p_acc: 0.5276 - 4s/epoch - 81ms/step
# Epoch 89/100
# 46/46 - 4s - c_loss: 0.5684 - c_acc: 0.9214 - r_acc: 0.5453 - p_loss: 1.0769 - p_acc: 0.4945 - val_p_loss: 3.8150 - val_p_acc: 0.5157 - 4s/epoch - 78ms/step
# Epoch 90/100
# 46/46 - 4s - c_loss: 0.4387 - c_acc: 0.9152 - r_acc: 0.5447 - p_loss: 0.7558 - p_acc: 0.4849 - val_p_loss: 3.6743 - val_p_acc: 0.5295 - 4s/epoch - 79ms/step
# Epoch 91/100
# 46/46 - 4s - c_loss: 0.4566 - c_acc: 0.9197 - r_acc: 0.5481 - p_loss: 1.2411 - p_acc: 0.5048 - val_p_loss: 4.0774 - val_p_acc: 0.5420 - 4s/epoch - 80ms/step
# Epoch 92/100
# 46/46 - 4s - c_loss: 0.4932 - c_acc: 0.9252 - r_acc: 0.5455 - p_loss: 1.1653 - p_acc: 0.4883 - val_p_loss: 4.0639 - val_p_acc: 0.5400 - 4s/epoch - 77ms/step
# Epoch 93/100
# 46/46 - 4s - c_loss: 0.6555 - c_acc: 0.9257 - r_acc: 0.5459 - p_loss: 1.0706 - p_acc: 0.4849 - val_p_loss: 3.7674 - val_p_acc: 0.5295 - 4s/epoch - 81ms/step
# Epoch 94/100
# 46/46 - 4s - c_loss: 0.4203 - c_acc: 0.9219 - r_acc: 0.5455 - p_loss: 1.2424 - p_acc: 0.4835 - val_p_loss: 4.6621 - val_p_acc: 0.5367 - 4s/epoch - 88ms/step
# Epoch 95/100
# 46/46 - 4s - c_loss: 0.3904 - c_acc: 0.9233 - r_acc: 0.5455 - p_loss: 1.7509 - p_acc: 0.4684 - val_p_loss: 4.4006 - val_p_acc: 0.5446 - 4s/epoch - 91ms/step
# Epoch 96/100
# 46/46 - 4s - c_loss: 0.4610 - c_acc: 0.9277 - r_acc: 0.5455 - p_loss: 0.9421 - p_acc: 0.5062 - val_p_loss: 3.7536 - val_p_acc: 0.5308 - 4s/epoch - 84ms/step
# Epoch 97/100
# 46/46 - 4s - c_loss: 0.5266 - c_acc: 0.9308 - r_acc: 0.5459 - p_loss: 1.1004 - p_acc: 0.4972 - val_p_loss: 4.0534 - val_p_acc: 0.5230 - 4s/epoch - 82ms/step
# Epoch 98/100
# 46/46 - 4s - c_loss: 0.4490 - c_acc: 0.9284 - r_acc: 0.5459 - p_loss: 0.9130 - p_acc: 0.4966 - val_p_loss: 3.8312 - val_p_acc: 0.5328 - 4s/epoch - 85ms/step
# Epoch 99/100
# 46/46 - 4s - c_loss: 0.5228 - c_acc: 0.9318 - r_acc: 0.5453 - p_loss: 0.8317 - p_acc: 0.5131 - val_p_loss: 3.6758 - val_p_acc: 0.5374 - 4s/epoch - 89ms/step
# Epoch 100/100
# 46/46 - 4s - c_loss: 0.4814 - c_acc: 0.9306 - r_acc: 0.5452 - p_loss: 1.4630 - p_acc: 0.5151 - val_p_loss: 4.1819 - val_p_acc: 0.5420 - 4s/epoch - 87ms/step

# %% [markdown]
# ### Plot the training loss and accuracy
#
# *Contrastive accuracy*: self-supervised metric, the ratio of cases in which the representation of an instance is more similar to its differently augmented version's one, than to the representation of any other instance in the current batch.
#
# *Correlation accuracy*: self-supervised metric, the ratio of cases in which the representation of an instance is more similar to its differently augmented version's one, than to the representation of any other instance in the queue.
#
# *Probe accuracy*: supervised metric, the ratio of cases in which the representation of an instance is more similar to its label's one, than to the representation of any other label.

# %%
print(pretrain_history.history.keys())
# Out:
# dict_keys(['c_loss', 'c_acc', 'r_acc', 'p_loss', 'p_acc', 'val_p_loss', 'val_p_acc'])

# %%
# summarize history for loss
plt.figure(figsize=(15, 10))
# plt.plot(pretrain_history.history['c_loss'])
plt.plot(pretrain_history.history['p_loss'])
plt.plot(pretrain_history.history['val_p_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['probe_loss', 'validation_prob_loss'], loc='upper right')
plt.show()

# %%
# summarize history for accuracy
plt.figure(figsize=(15, 10))
plt.plot(pretrain_history.history['c_acc'])
plt.plot(pretrain_history.history['r_acc'])
plt.plot(pretrain_history.history['p_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['contrastive_accuracy', 'correlation_accuracy', 'probe_accuracy'], loc='upper left')
plt.show()

# %% [markdown]
# ## Plot the learned representations using UMAP
#
# Plot the representations of the labeled data in the representation space learned by the NNCLR encoder. Use UMAP to reduce the dimensionality to 2. The color of each point corresponds to its label.

# %%
import matplotlib.pyplot as plt
plt.rc('font', size=12)          # controls default text sizes
plt.rc('axes', titlesize=16)     # fontsize of the axes title
plt.rc('axes', labelsize=12)    # fontsize of the x and y labels
plt.rc('legend', fontsize=12)    # legend fontsize
plt.rc('figure', titlesize=16)  # fontsize of the figure title

# %%
# Plot the representations of the unlabeled data in the representation space learned by the NNCLR encoder. Use UMAP to reduce the dimensionality to 2. The color of each point corresponds to its label.

import umap.umap_ as umap
import numpy as np

# Get the representations of the unlabeled data.
unlabeled_feature_vectors = model.encoder(x_train, training=False)

# Reduce the dimensionality of the representations to 2.
reducer = umap.UMAP()
umap_embeddings = reducer.fit_transform(unlabeled_feature_vectors)

# Plot the representations.
plt.figure(figsize=(12, 10))
plt.scatter(umap_embeddings[:, 0], umap_embeddings[:, 1], c=y_train, s=5.0, cmap='Spectral')
# plt.gca().set_aspect('equal', 'datalim')
plt.colorbar(boundaries=np.arange(n_classes+1)-0.5).set_ticks(np.arange(n_classes))
plt.title('UMAP projection of the representations of the unlabeled data')
# Out:
# Text(0.5, 1.0, 'UMAP projection of the representations of the unlabeled data')

# %%
# Plot the representations of the labeled data in the representation space learned by the NNCLR encoder. Use UMAP to reduce the dimensionality to 2.

# Get the representations of the labeled data.
labeled_feature_vectors = model.encoder(x_validate, training=False)

# Reduce the dimensionality of the representations to 2.
# reducer = umap.UMAP()
# umap_embeddings = reducer.fit_transform(labeled_feature_vectors)
umap_embeddings = reducer.transform(labeled_feature_vectors)

# Plot the representations.
plt.figure(figsize=(12, 10))
plt.scatter(umap_embeddings[:, 0], umap_embeddings[:, 1], c=y_validate, s=5.0, cmap='Spectral')
# plt.gca().set_aspect('equal', 'datalim')
plt.colorbar(boundaries=np.arange(n_classes+1)-0.5).set_ticks(np.arange(n_classes))
plt.title('UMAP projection of the representations of the labeled data')
# Out:
# Text(0.5, 1.0, 'UMAP projection of the representations of the labeled data')

# %%
# Plot the representations of the test data in the representation space learned by the NNCLR encoder. Use UMAP to reduce the dimensionality to 2. The color of each point corresponds to its label.

# Get the representations of the test data.
test_feature_vectors = model.encoder(x_test, training=False)

# Reduce the dimensionality of the representations to 2.
# reducer = umap.UMAP()
# umap_embeddings = reducer.fit_transform(test_feature_vectors)
umap_embeddings = reducer.transform(test_feature_vectors)

# Plot the representations.
plt.figure(figsize=(12, 10))
plt.scatter(umap_embeddings[:, 0], umap_embeddings[:, 1], c=y_test, s=5.0, cmap='Spectral')
# plt.gca().set_aspect('equal', 'datalim')
plt.colorbar(boundaries=np.arange(n_classes+1)-0.5).set_ticks(np.arange(n_classes))
plt.title('UMAP projection of the representations of the test data')
# Out:
# Text(0.5, 1.0, 'UMAP projection of the representations of the test data')

# %% [markdown]
# ## Fine tune the model
#
# Fine tune the NNCLR encoder on the labeled data. The classifier is trained on the labeled data.

# %%
finetuning_model = keras.Sequential(
    [
        layers.Input(shape=input_shape),
        augmenter("classification_augmenter", input_shape=input_shape),
        model.encoder,
        layers.Dense(n_classes),
    ],
    name="finetuning_model",
)
finetuning_model.compile(
    optimizer=keras.optimizers.Adam(),
    loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=[keras.metrics.SparseCategoricalAccuracy(name="acc")],
    run_eagerly=None # True = run eagerly, False = run as graph, None = autodetect
)

finetuning_history = finetuning_model.fit(
    labeled_train_dataset, epochs=finetune_num_epochs, validation_data=test_dataset
)
# Out:
# Epoch 1/100
# 46/46 [==============================] - 3s 39ms/step - loss: 3.8006 - acc: 0.1039 - val_loss: 2.1635 - val_acc: 0.2533
# Epoch 2/100
# 46/46 [==============================] - 1s 32ms/step - loss: 2.1595 - acc: 0.2490 - val_loss: 2.0831 - val_acc: 0.2710
# Epoch 3/100
# 46/46 [==============================] - 1s 31ms/step - loss: 2.0959 - acc: 0.2696 - val_loss: 1.9090 - val_acc: 0.3156
# Epoch 4/100
# 46/46 [==============================] - 1s 30ms/step - loss: 1.9014 - acc: 0.3019 - val_loss: 1.6547 - val_acc: 0.3688
# Epoch 5/100
# 46/46 [==============================] - 1s 31ms/step - loss: 1.5775 - acc: 0.3810 - val_loss: 1.4845 - val_acc: 0.4678
# Epoch 6/100
# 46/46 [==============================] - 2s 33ms/step - loss: 1.3954 - acc: 0.4477 - val_loss: 1.3554 - val_acc: 0.5282
# Epoch 7/100
# 46/46 [==============================] - 1s 32ms/step - loss: 1.3024 - acc: 0.5330 - val_loss: 1.2809 - val_acc: 0.5354
# Epoch 8/100
# 46/46 [==============================] - 1s 29ms/step - loss: 1.1985 - acc: 0.5309 - val_loss: 1.1476 - val_acc: 0.5741
# Epoch 9/100
# 46/46 [==============================] - 1s 29ms/step - loss: 1.0892 - acc: 0.5743 - val_loss: 1.1317 - val_acc: 0.5873
# Epoch 10/100
# 46/46 [==============================] - 1s 32ms/step - loss: 0
history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train_loss', 'test_loss'], loc='upper right')
plt.show()

# %%
# summarize history for accuracy
plt.plot(finetuning_history.history['acc'])
plt.plot(finetuning_history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train_accuracy', 'test_accuracy'], loc='upper left')
plt.show()

# %% [markdown]
# ## Evaluate our fine tuned model on the test set

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
import pandas as pd
import seaborn as sns
import numpy as np

#### Show results
predictions = finetuning_model.predict(test_dataset, verbose=0, batch_size=32)
#must use values not one-hot encoding, use argmax to convert
y_pred = np.argmax(predictions, axis=-1) # axis=-1 means last axis
y_test = np.concatenate([y for x, y in test_dataset], axis=0)
print('Prediction accuracy: {0:.3f}'.format(accuracy_score(y_test, y_pred)))

t_names = np.unique(y_test).astype(str)

print(classification_report(y_test, y_pred, target_names=t_names))
cm = confusion_matrix(y_test, y_pred)
print(cm)
cm_df = pd.DataFrame(cm,
                     index = t_names, 
                     columns = t_names)
fig = plt.figure(figsize=(6.5,5))
sns.heatmap(cm_df, annot=True, fmt='d', cmap='cubehelix_r')
plt.title('1D CNN using e4_Nov2019'+'\nAccuracy:{0:.3f}'.format(accuracy_score(y_test, y_pred)))
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.tight_layout() # keeps labels from being cutoff when saving as pdf
plt.show()
# Out:
# Prediction accuracy: 0.789
#               precision    recall  f1-score   support
#
#            0       0.75      0.44      0.56        34
#            1       0.56      0.74      0.64        47
#            2       0.81      0.53      0.64       344
#            3       0.99      0.99      0.99       413
#            4       0.59      0.79      0.67       184
#            5       0.90      0.82      0.86       146
#            6       0.71      0.91      0.79       256
#            7       0.70      0.79      0.74        68
#            8       0.57      0.38      0.45        32
#
#     accuracy                           0.79      1524
#    macro avg       0.73      0.71      0.71      1524
# weighted avg       0.80      0.79      0.78      1524
#
# [[ 15  17   0   0   0   0   0   2   0]
#  [  4  35   0   0   0   0   0   3   5]
#  [  0   0 183   1  95   3  62   0   0]
#  [  0   0   2 407   0   0   4   0   0]
#  [  0   1  23   1 145   2  12   0   0]
#  [  0   0   6   1   3 119  17   0   0]
#  [  0   1   9   2   4   8 232   0   0]
#  [  0   8   1   0   0   0   1  54   4]
#  [  1   0   1   0   0   0   0  18  12]]

# %% [markdown]
# ## Evaluate the learned representations using a KNN classifier

# %%
from sklearn.neighbors import KNeighborsClassifier

# Convert train dataset to feature vectors using the self-supervised encoder
train_feature_vectors = model.encoder(x_train, training=False)

knn = KNeighborsClassifier(n_neighbors=3)
knn_model = knn.fit(train_feature_vectors, y_train)

# Predict test set with the knn model
test_feature_vectors = model.encoder(x_test, training=False)
y_pred = knn_model.predict(test_feature_vectors)

print('Prediction accuracy: {0:.3f}'.format(accuracy_score(y_test, y_pred)))
print(classification_report(y_test, y_pred, target_names=t_names))
cm = confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# Prediction accuracy: 0.714
#               precision    recall  f1-score   support
#
#            0       0.42      0.74      0.53        34
#            1       0.34      0.32      0.33        47
#            2       0.60      0.80      0.69       344
#            3       0.96      0.96      0.96       413
#            4       0.52      0.53      0.53       184
#            5       0.93      0.77      0.84       146
#            6       0.71      0.50      0.59       256
#            7       0.67      0.29      0.41        68
#            8       0.55      0.53      0.54        32
#
#     accuracy                           0.71      1524
#    macro avg       0.63      0.60      0.60      1524
# weighted avg       0.73      0.71      0.71      1524
#
# [[ 25   7   0   0   0   0   2   0   0]
#  [ 22  15   1   0   1   0   0   4   4]
#  [  0   0 275   1  40   5  23   0   0]
#  [  0   0   8 398   0   0   7   0   0]
#  [  0   5  73   1  98   0   6   0   1]
#  [  0   0   8  11   4 112  11   0   0]
#  [  0   0  85   3  36   4 128   0   0]
#  [ 10  14   6   0   6   0   3  20   9]
#  [  3   3   0   0   3   0   0   6  17]]
