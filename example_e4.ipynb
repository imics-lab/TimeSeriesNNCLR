# %% [markdown]
# # NNCLR example on the [E4 dataset](https://zenodo.org/records/5911808)

# %% [markdown]
# ## Imports

# %%
import matplotlib.pyplot as plt
import numpy as np
from tensorflow import keras
from tensorflow.keras import layers

from data_loader import load_e4_dataset
from augmentations import augmenter
# from encoder import encoder
from nnclr import NNCLR 

# %matplotlib inline

# %% [markdown]
# ## Load the data
#
# NNCLR takes in both the unlabeled and labeled data. The self-supervised encoder is trained on both the labeled and unlabeled data. The labeled data is used to train the classifier.

# %%
(batch_size, train_dataset, unlabeled_train_dataset, labeled_train_dataset, test_dataset, 
    x_train, y_train, x_validate, y_validate, x_test, y_test) = load_e4_dataset()

n_classes = np.unique(y_train).shape[0]  # the number of classes in the dataset
# Out:
# Processing  1574621345_A01F11.zip
# Unzipping e4 file in local directory c:\Users\vangelis\Files\Academia\Research\DeepLearning\Self-Supervised-Learning\NNCLR_keras\TimeSeriesNNCLR/temp
# c:\Users\vangelis\Files\Academia\Research\DeepLearning\Self-Supervised-Learning\NNCLR_keras\TimeSeriesNNCLR/temp/ACC.csv Sample frequency =  32.0  Hz
# File start time =  Sun, 24 Nov 2019 12:49:05
# File end time   =  Sun, 24 Nov 2019 12:58:11
# Tag info (button presses) from tags.csv
#     UTC_time          Local Time
# 0 1574621375.17 Sun, 24 Nov 2019 12:49:35
# 1 1574621774.22 Sun, 24 Nov 2019 12:56:14
# Warning: Multiple subjects detected in csv, unusual for e4 data.
# Label Counts
#  label
# Upstairs      6208
# Downstairs    5889
# Undefined     5405
# Name: count, dtype: int64
# No NaN entries found
# shapes call broke when making the function - not sure why
# Processing  1574622389_A01F11.zip
# Unzipping e4 file in local directory c:\Users\vangelis\Files\Academia\Research\DeepLearning\Self-Supervised-Learning\NNCLR_keras\TimeSeriesNNCLR/temp
# c:\Users\vangelis\Files\Academia\Research\DeepLearning\Self-Supervised-Learning\NNCLR_keras\TimeSeriesNNCLR/temp/ACC.csv Sample frequency =  32.0  Hz
# File start time =  Sun, 24 Nov 2019 13:06:29
# File end time   =  Sun, 24 Nov 2019 13:15:03
# Tag info (button presses) from tags.csv
#     UTC_time          Local Time
# 0 1574622432.21 Sun, 24 Nov 2019 13:07:12
# 1 1574622822.72 Sun, 24 Nov 2019 13:13:42
# Warning: Multiple subjects detected in csv, unusual for e4 data.
# Label Counts
#  label
# Walking      5793
# Jogging      5792
# Undefined    4885
# Name: count, dtype: int64
# No NaN entries found
# shapes call broke when making the function - not sure why
# Processing  1574624998_A01F11.zip
# Unzipping e4 file in local directory c:\Users\vangelis\Files\Academia\Research\DeepLearning\Self-Supervised-Learning\NNCLR_keras\TimeSeriesNNCLR/temp
# c:\Users\vangelis\Files\Academia\Research\DeepLearning\Self-Supervised-Learning\NNCLR_keras\TimeSeriesNNCLR/temp/ACC.csv Sample frequency =  32.0  Hz
# File start time =  Sun, 24 Nov 2019 13:49:58
# File end time   =  Sun, 24 Nov 2019 13:57:15
# Tag info (button presses) from tags.csv
#     UTC_time          Local Time
# 0 1574625042.71 Sun, 24 Nov 2019 13:50:42
# 1 1574625419.43 Sun, 24 Nov 2019 13:56:59
# Warning: Multiple subjects detected in csv, unusual for e4 data.
# Label Counts
#  label
# Sitting      5857
# Standing     5632
# Undefined    2503
# Name: count, dtype: int64
# No NaN entries found
# shapes call broke when making the function - not sure why
# shapes call broke when making the function - not sure why
# Final Label Counts
# [['Downstairs' '170']
#  ['Jogging' '175']
#  ['Sitting' '177']
#  ['Standing' '170']
#  ['Upstairs' '180']
#  ['Walking' '175']]
# e4 November 2019 zip files
# 1574621345_A01F11.zip 1574622389_A01F11.zip 1574624998_A01F11.zip
# Time steps =96, Step =32, no resample
# Final Shapes
# shapes call broke when making the function - not sure why
# Not one-hot-encoding
# {'Downstairs': 0, 'Jogging': 1, 'Sitting': 2, 'Standing': 3, 'Upstairs': 4, 'Walking': 5}
# x_train shape: (380, 96, 4)
# y_train shape: (380,)
# x_validate shape: (329, 96, 4)
# y_validate shape: (329,)
# x_test shape: (338, 96, 4)
# y_test shape: (338,)

# %%
print("x_train shape:", x_train.shape)
print("y_train shape:", y_train.shape)
print("x_validate shape:", x_validate.shape)
print("y_validate shape:", y_validate.shape)
print("x_test shape:", x_test.shape)
print("y_test shape:", y_test.shape)
# Out:
# x_train shape: (380, 96, 4)
# y_train shape: (380,)
# x_validate shape: (329, 96, 4)
# y_validate shape: (329,)
# x_test shape: (338, 96, 4)
# y_test shape: (338,)

# %% [markdown]
# ## Set configuration parameters

# %%
### Hyperparameters
temperature = 0.1        # the temperature for the softmax function in the contrastive loss
queue_size = 1000        # the size of the queue for storing the feature vectors

width = 64                  # the size of the output embedding vector for each sequence
pretrain_num_epochs = 100   # the number of epochs to pretrain the model
finetune_num_epochs = 100    # The number of epochs to fine-tune the model.

# %% [markdown]
# ## Pre-train NNCLR

# %% [markdown]
# ### Specify the encoder architecture

# %%
input_shape = x_train[0].shape # Get the shape from the first element of the training set

# Create the encoder model
encoder_model = keras.Sequential(
		[
			keras.Input(shape=input_shape),
			layers.Conv1D(filters=100, kernel_size=9, activation='relu'),
			layers.Conv1D(filters=100, kernel_size=9, activation='relu'),
			layers.Dropout(0.5),
			layers.MaxPooling1D(pool_size=2),
			layers.Flatten(),
			layers.Dense(width, activation='relu')
   		],
        name="encoder_model",
    )
encoder_model.summary()
# Out:
# Model: "encoder_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 88, 100)           3700
#
#  conv1d_1 (Conv1D)           (None, 80, 100)           90100
#
#  dropout (Dropout)           (None, 80, 100)           0
#
#  max_pooling1d (MaxPooling1  (None, 40, 100)           0
#  D)
#
#  flatten (Flatten)           (None, 4000)              0
#
#  dense (Dense)               (None, 64)                256064
#
# =================================================================
# Total params: 349864 (1.33 MB)
# Trainable params: 349864 (1.33 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### Perform self-supervised training

# %%
model = NNCLR(temperature=temperature, queue_size=queue_size, input_shape=input_shape, output_width=width, n_classes= n_classes, encoder=encoder_model)

model.compile(
    contrastive_optimizer=keras.optimizers.Adam(),
    probe_optimizer=keras.optimizers.Adam(),
    run_eagerly=None # True = run eagerly, False = run as graph, None = autodetect
)

model.build(input_shape=(None, input_shape[0], input_shape[1]))
model.summary()
# Out:
# Model: "nnclr"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  contrastive_augmenter (Seq  (None, None, 4)           0
#  uential)
#
#  classification_augmenter (  (None, None, 4)           0
#  Sequential)
#
#  encoder_model (Sequential)  (None, 64)                349864
#
#  projection_head (Sequentia  (None, 64)                8320
#  l)
#
#  linear_probe (Sequential)   (None, 6)                 390
#
# =================================================================
# Total params: 422580 (1.61 MB)
# Trainable params: 358574 (1.37 MB)
# Non-trainable params: 64006 (250.02 KB)
# _________________________________________________________________

# %%
pretrain_history = model.fit(
    train_dataset, epochs=pretrain_num_epochs, validation_data=test_dataset, 
    verbose=2 # 0 = silent, 1 = progress bar, 2 = one line per epoch, 3 = one line per batch
              # Due to a weird bug, the fit function crashes if verbose is set to 1.
)
# Out:
# Epoch 1/100
# 11/11 - 4s - c_loss: 3.6920 - c_acc: 0.0294 - r_acc: 0.0440 - p_loss: 1.9758 - p_acc: 0.1489 - val_p_loss: 1.7607 - val_p_acc: 0.1450 - 4s/epoch - 403ms/step
# Epoch 2/100
# 11/11 - 0s - c_loss: 3.4811 - c_acc: 0.0830 - r_acc: 0.1115 - p_loss: 2.0093 - p_acc: 0.1489 - val_p_loss: 1.7449 - val_p_acc: 0.1450 - 481ms/epoch - 44ms/step
# Epoch 3/100
# 11/11 - 1s - c_loss: 3.2819 - c_acc: 0.1248 - r_acc: 0.1960 - p_loss: 1.9805 - p_acc: 0.1489 - val_p_loss: 1.7477 - val_p_acc: 0.1450 - 516ms/epoch - 47ms/step
# Epoch 4/100
# 11/11 - 0s - c_loss: 2.8313 - c_acc: 0.1821 - r_acc: 0.2372 - p_loss: 1.9451 - p_acc: 0.1489 - val_p_loss: 1.7585 - val_p_acc: 0.1450 - 496ms/epoch - 45ms/step
# Epoch 5/100
# 11/11 - 1s - c_loss: 2.4886 - c_acc: 0.2056 - r_acc: 0.2820 - p_loss: 1.9548 - p_acc: 0.1641 - val_p_loss: 1.7512 - val_p_acc: 0.1450 - 534ms/epoch - 49ms/step
# Epoch 6/100
# 11/11 - 1s - c_loss: 2.3424 - c_acc: 0.2173 - r_acc: 0.2955 - p_loss: 1.9310 - p_acc: 0.1611 - val_p_loss: 1.7441 - val_p_acc: 0.1450 - 526ms/epoch - 48ms/step
# Epoch 7/100
# 11/11 - 1s - c_loss: 2.3901 - c_acc: 0.2606 - r_acc: 0.3089 - p_loss: 1.9063 - p_acc: 0.1489 - val_p_loss: 1.7614 - val_p_acc: 0.1450 - 500ms/epoch - 45ms/step
# Epoch 8/100
# 11/11 - 1s - c_loss: 1.8425 - c_acc: 0.2974 - r_acc: 0.3359 - p_loss: 1.9175 - p_acc: 0.2766 - val_p_loss: 1.7403 - val_p_acc: 0.2544 - 535ms/epoch - 49ms/step
# Epoch 9/100
# 11/11 - 1s - c_loss: 2.1332 - c_acc: 0.3047 - r_acc: 0.3267 - p_loss: 1.9066 - p_acc: 0.2918 - val_p_loss: 1.7466 - val_p_acc: 0.2219 - 554ms/epoch - 50ms/step
# Epoch 10/100
# 11/11 - 0s - c_loss: 2.2815 - c_acc: 0.2856 - r_acc: 0.3395 - p_loss: 1.9028 - p_acc: 0.3070 - val_p_loss: 1.7480 - val_p_acc: 0.1893 - 493ms/epoch - 45ms/step
# Epoch 11/100
# 11/11 - 0s - c_loss: 1.9818 - c_acc: 0.3150 - r_acc: 0.3430 - p_loss: 1.8792 - p_acc: 0.3161 - val_p_loss: 1.7525 - val_p_acc: 0.1923 - 487ms/epoch - 44ms/step
# Epoch 12/100
# 11/11 - 0s - c_loss: 1.7712 - c_acc: 0.3260 - r_acc: 0.3445 - p_loss: 1.8666 - p_acc: 0.3161 - val_p_loss: 1.7473 - val_p_acc: 0.2870 - 468ms/epoch - 43ms/step
# Epoch 13/100
# 11/11 - 0s - c_loss: 1.7617 - c_acc: 0.3385 - r_acc: 0.3409 - p_loss: 1.8534 - p_acc: 0.3161 - val_p_loss: 1.7393 - val_p_acc: 0.3166 - 483ms/epoch - 44ms/step
# Epoch 14/100
# 11/11 - 1s - c_loss: 1.5979 - c_acc: 0.3708 - r_acc: 0.3438 - p_loss: 1.8419 - p_acc: 0.3191 - val_p_loss: 1.7344 - val_p_acc: 0.3195 - 507ms/epoch - 46ms/step
# Epoch 15/100
# 11/11 - 0s - c_loss: 1.6583 - c_acc: 0.3649 - r_acc: 0.3537 - p_loss: 1.8487 - p_acc: 0.3131 - val_p_loss: 1.7185 - val_p_acc: 0.3254 - 497ms/epoch - 45ms/step
# Epoch 16/100
# 11/11 - 0s - c_loss: 1.6438 - c_acc: 0.3561 - r_acc: 0.3580 - p_loss: 1.8655 - p_acc: 0.3191 - val_p_loss: 1.7177 - val_p_acc: 0.3166 - 484ms/epoch - 44ms/step
# Epoch 17/100
# 11/11 - 0s - c_loss: 1.7192 - c_acc: 0.3612 - r_acc: 0.3516 - p_loss: 1.8542 - p_acc: 0.3161 - val_p_loss: 1.6950 - val_p_acc: 0.3195 - 494ms/epoch - 45ms/step
# Epoch 18/100
# 11/11 - 1s - c_loss: 1.6073 - c_acc: 0.3811 - r_acc: 0.3558 - p_loss: 1.8651 - p_acc: 0.3222 - val_p_loss: 1.7105 - val_p_acc: 0.3225 - 611ms/epoch - 56ms/step
# Epoch 19/100
# 11/11 - 1s - c_loss: 1.7521 - c_acc: 0.3598 - r_acc: 0.3509 - p_loss: 1.8386 - p_acc: 0.3161 - val_p_loss: 1.7263 - val_p_acc: 0.2840 - 562ms/epoch - 51ms/step
# Epoch 20/100
# 11/11 - 1s - c_loss: 1.5893 - c_acc: 0.3891 - r_acc: 0.3516 - p_loss: 1.8274 - p_acc: 0.3222 - val_p_loss: 1.6894 - val_p_acc: 0.3195 - 503ms/epoch - 46ms/step
# Epoch 21/100
# 11/11 - 0s - c_loss: 1.5974 - c_acc: 0.3561 - r_acc: 0.3516 - p_loss: 1.8132 - p_acc: 0.3161 - val_p_loss: 1.6868 - val_p_acc: 0.2692 - 481ms/epoch - 44ms/step
# Epoch 22/100
# 11/11 - 1s - c_loss: 1.6106 - c_acc: 0.3612 - r_acc: 0.3572 - p_loss: 1.7980 - p_acc: 0.2948 - val_p_loss: 1.7011 - val_p_acc: 0.2574 - 507ms/epoch - 46ms/step
# Epoch 23/100
# 11/11 - 1s - c_loss: 1.5739 - c_acc: 0.3877 - r_acc: 0.3516 - p_loss: 1.8069 - p_acc: 0.2948 - val_p_loss: 1.6681 - val_p_acc: 0.2840 - 506ms/epoch - 46ms/step
# Epoch 24/100
# 11/11 - 1s - c_loss: 1.2878 - c_acc: 0.3833 - r_acc: 0.3572 - p_loss: 1.8133 - p_acc: 0.2857 - val_p_loss: 1.6761 - val_p_acc: 0.2722 - 534ms/epoch - 49ms/step
# Epoch 25/100
# 11/11 - 1s - c_loss: 1.6890 - c_acc: 0.3774 - r_acc: 0.3530 - p_loss: 1.8155 - p_acc: 0.3556 - val_p_loss: 1.6513 - val_p_acc: 0.3491 - 514ms/epoch - 47ms/step
# Epoch 26/100
# 11/11 - 1s - c_loss: 1.6271 - c_acc: 0.3708 - r_acc: 0.3494 - p_loss: 1.8059 - p_acc: 0.3465 - val_p_loss: 1.6688 - val_p_acc: 0.3254 - 515ms/epoch - 47ms/step
# Epoch 27/100
# 11/11 - 1s - c_loss: 1.3746 - c_acc: 0.3950 - r_acc: 0.3601 - p_loss: 1.8224 - p_acc: 0.4012 - val_p_loss: 1.6654 - val_p_acc: 0.3432 - 538ms/epoch - 49ms/step
# Epoch 28/100
# 11/11 - 1s - c_loss: 1.6674 - c_acc: 0.4082 - r_acc: 0.3523 - p_loss: 1.8065 - p_acc: 0.3617 - val_p_loss: 1.6481 - val_p_acc: 0.3166 - 507ms/epoch - 46ms/step
# Epoch 29/100
# 11/11 - 0s - c_loss: 1.4071 - c_acc: 0.4097 - r_acc: 0.3530 - p_loss: 1.7686 - p_acc: 0.4681 - val_p_loss: 1.6008 - val_p_acc: 0.4763 - 495ms/epoch - 45ms/step
# Epoch 30/100
# 11/11 - 0s - c_loss: 1.4237 - c_acc: 0.4207 - r_acc: 0.3480 - p_loss: 1.7735 - p_acc: 0.4468 - val_p_loss: 1.5658 - val_p_acc: 0.4379 - 485ms/epoch - 44ms/step
# Epoch 31/100
# 11/11 - 0s - c_loss: 1.2253 - c_acc: 0.4207 - r_acc: 0.3558 - p_loss: 1.7596 - p_acc: 0.5046 - val_p_loss: 1.5740 - val_p_acc: 0.4763 - 467ms/epoch - 42ms/step
# Epoch 32/100
# 11/11 - 0s - c_loss: 1.2718 - c_acc: 0.4435 - r_acc: 0.3530 - p_loss: 1.7668 - p_acc: 0.4924 - val_p_loss: 1.5860 - val_p_acc: 0.5000 - 485ms/epoch - 44ms/step
# Epoch 33/100
# 11/11 - 1s - c_loss: 1.2152 - c_acc: 0.4530 - r_acc: 0.3494 - p_loss: 1.7522 - p_acc: 0.5106 - val_p_loss: 1.5791 - val_p_acc: 0.4970 - 509ms/epoch - 46ms/step
# Epoch 34/100
# 11/11 - 0s - c_loss: 1.1935 - c_acc: 0.4420 - r_acc: 0.3572 - p_loss: 1.7533 - p_acc: 0.5046 - val_p_loss: 1.6138 - val_p_acc: 0.3994 - 484ms/epoch - 44ms/step
# Epoch 35/100
# 11/11 - 0s - c_loss: 1.3677 - c_acc: 0.4648 - r_acc: 0.3636 - p_loss: 1.7369 - p_acc: 0.5076 - val_p_loss: 1.5759 - val_p_acc: 0.4556 - 485ms/epoch - 44ms/step
# Epoch 36/100
# 11/11 - 1s - c_loss: 1.7628 - c_acc: 0.4442 - r_acc: 0.3615 - p_loss: 1.7413 - p_acc: 0.4590 - val_p_loss: 1.5824 - val_p_acc: 0.3876 - 516ms/epoch - 47ms/step
# Epoch 37/100
# 11/11 - 1s - c_loss: 1.1757 - c_acc: 0.4604 - r_acc: 0.3572 - p_loss: 1.7367 - p_acc: 0.4894 - val_p_loss: 1.5070 - val_p_acc: 0.4763 - 504ms/epoch - 46ms/step
# Epoch 38/100
# 11/11 - 1s - c_loss: 1.2471 - c_acc: 0.4662 - r_acc: 0.3509 - p_loss: 1.7560 - p_acc: 0.4924 - val_p_loss: 1.4837 - val_p_acc: 0.4793 - 546ms/epoch - 50ms/step
# Epoch 39/100
# 11/11 - 1s - c_loss: 1.4054 - c_acc: 0.4941 - r_acc: 0.3594 - p_loss: 1.7051 - p_acc: 0.5076 - val_p_loss: 1.4731 - val_p_acc: 0.4941 - 528ms/epoch - 48ms/step
# Epoch 40/100
# 11/11 - 1s - c_loss: 1.2124 - c_acc: 0.4890 - r_acc: 0.3601 - p_loss: 1.6787 - p_acc: 0.4954 - val_p_loss: 1.4661 - val_p_acc: 0.4882 - 505ms/epoch - 46ms/step
# Epoch 41/100
# 11/11 - 1s - c_loss: 1.1890 - c_acc: 0.4787 - r_acc: 0.3608 - p_loss: 1.6842 - p_acc: 0.5046 - val_p_loss: 1.5123 - val_p_acc: 0.4970 - 502ms/epoch - 46ms/step
# Epoch 42/100
# 11/11 - 1s - c_loss: 1.2157 - c_acc: 0.4816 - r_acc: 0.3608 - p_loss: 1.6874 - p_acc: 0.5076 - val_p_loss: 1.4150 - val_p_acc: 0.5089 - 533ms/epoch - 48ms/step
# Epoch 43/100
# 11/11 - 1s - c_loss: 1.3102 - c_acc: 0.5000 - r_acc: 0.3636 - p_loss: 1.6908 - p_acc: 0.5015 - val_p_loss: 1.4309 - val_p_acc: 0.5030 - 531ms/epoch - 48ms/step
# Epoch 44/100
# 11/11 - 0s - c_loss: 1.2800 - c_acc: 0.4941 - r_acc: 0.3686 - p_loss: 1.7027 - p_acc: 0.4225 - val_p_loss: 1.2886 - val_p_acc: 0.4408 - 482ms/epoch - 44ms/step
# Epoch 45/100
# 11/11 - 0s - c_loss: 1.4011 - c_acc: 0.4927 - r_acc: 0.3643 - p_loss: 1.6591 - p_acc: 0.5076 - val_p_loss: 1.4110 - val_p_acc: 0.5089 - 473ms/epoch - 43ms/step
# Epoch 46/100
# 11/11 - 1s - c_loss: 1.1368 - c_acc: 0.5037 - r_acc: 0.3643 - p_loss: 1.6877 - p_acc: 0.5076 - val_p_loss: 1.3200 - val_p_acc: 0.5118 - 517ms/epoch - 47ms/step
# Epoch 47/100
# 11/11 - 1s - c_loss: 1.1534 - c_acc: 0.5228 - r_acc: 0.3722 - p_loss: 1.6561 - p_acc: 0.5076 - val_p_loss: 1.4497 - val_p_acc: 0.4941 - 520ms/epoch - 47ms/step
# Epoch 48/100
# 11/11 - 1s - c_loss: 1.3365 - c_acc: 0.5308 - r_acc: 0.3757 - p_loss: 1.6482 - p_acc: 0.5046 - val_p_loss: 1.3333 - val_p_acc: 0.5148 - 554ms/epoch - 50ms/step
# Epoch 49/100
# 11/11 - 1s - c_loss: 1.2413 - c_acc: 0.5264 - r_acc: 0.3764 - p_loss: 1.7421 - p_acc: 0.3647 - val_p_loss: 1.5634 - val_p_acc: 0.3491 - 531ms/epoch - 48ms/step
# Epoch 50/100
# 11/11 - 0s - c_loss: 1.3288 - c_acc: 0.5242 - r_acc: 0.3764 - p_loss: 1.7167 - p_acc: 0.4772 - val_p_loss: 1.4049 - val_p_acc: 0.4231 - 490ms/epoch - 45ms/step
# Epoch 51/100
# 11/11 - 1s - c_loss: 1.4659 - c_acc: 0.5352 - r_acc: 0.3700 - p_loss: 1.6645 - p_acc: 0.5076 - val_p_loss: 1.3859 - val_p_acc: 0.5089 - 523ms/epoch - 48ms/step
# Epoch 52/100
# 11/11 - 1s - c_loss: 1.1460 - c_acc: 0.5323 - r_acc: 0.3743 - p_loss: 1.6460 - p_acc: 0.5106 - val_p_loss: 1.2592 - val_p_acc: 0.5148 - 568ms/epoch - 52ms/step
# Epoch 53/100
# 11/11 - 1s - c_loss: 1.1351 - c_acc: 0.5294 - r_acc: 0.3729 - p_loss: 1.6495 - p_acc: 0.5106 - val_p_loss: 1.1945 - val_p_acc: 0.5148 - 510ms/epoch - 46ms/step
# Epoch 54/100
# 11/11 - 1s - c_loss: 0.8702 - c_acc: 0.5176 - r_acc: 0.3615 - p_loss: 1.6118 - p_acc: 0.5137 - val_p_loss: 1.1255 - val_p_acc: 0.5118 - 536ms/epoch - 49ms/step
# Epoch 55/100
# 11/11 - 1s - c_loss: 1.0671 - c_acc: 0.5477 - r_acc: 0.3636 - p_loss: 1.6058 - p_acc: 0.5076 - val_p_loss: 1.1342 - val_p_acc: 0.5118 - 505ms/epoch - 46ms/step
# Epoch 56/100
# 11/11 - 1s - c_loss: 1.2014 - c_acc: 0.5396 - r_acc: 0.3643 - p_loss: 1.6321 - p_acc: 0.5046 - val_p_loss: 1.1166 - val_p_acc: 0.5118 - 512ms/epoch - 47ms/step
# Epoch 57/100
# 11/11 - 1s - c_loss: 0.9938 - c_acc: 0.5272 - r_acc: 0.3722 - p_loss: 1.6517 - p_acc: 0.5106 - val_p_loss: 1.0784 - val_p_acc: 0.5118 - 605ms/epoch - 55ms/step
# Epoch 58/100
# 11/11 - 1s - c_loss: 1.1527 - c_acc: 0.5242 - r_acc: 0.3679 - p_loss: 1.5714 - p_acc: 0.5076 - val_p_loss: 0.9829 - val_p_acc: 0.5000 - 516ms/epoch - 47ms/step
# Epoch 59/100
# 11/11 - 1s - c_loss: 1.1385 - c_acc: 0.5345 - r_acc: 0.3651 - p_loss: 1.6619 - p_acc: 0.5015 - val_p_loss: 1.1431 - val_p_acc: 0.5118 - 624ms/epoch - 57ms/step
# Epoch 60/100
# 11/11 - 1s - c_loss: 1.1283 - c_acc: 0.5514 - r_acc: 0.3665 - p_loss: 1.6553 - p_acc: 0.5076 - val_p_loss: 1.0920 - val_p_acc: 0.5118 - 520ms/epoch - 47ms/step
# Epoch 61/100
# 11/11 - 0s - c_loss: 1.1200 - c_acc: 0.5646 - r_acc: 0.3636 - p_loss: 1.5674 - p_acc: 0.5106 - val_p_loss: 0.9451 - val_p_acc: 0.5148 - 483ms/epoch - 44ms/step
# Epoch 62/100
# 11/11 - 1s - c_loss: 1.1451 - c_acc: 0.5088 - r_acc: 0.3636 - p_loss: 1.6180 - p_acc: 0.5106 - val_p_loss: 1.0055 - val_p_acc: 0.5118 - 501ms/epoch - 46ms/step
# Epoch 63/100
# 11/11 - 1s - c_loss: 1.1750 - c_acc: 0.5323 - r_acc: 0.3700 - p_loss: 1.5738 - p_acc: 0.5076 - val_p_loss: 0.9358 - val_p_acc: 0.5118 - 507ms/epoch - 46ms/step
# Epoch 64/100
# 11/11 - 1s - c_loss: 1.0349 - c_acc: 0.5529 - r_acc: 0.3750 - p_loss: 1.6580 - p_acc: 0.5106 - val_p_loss: 0.9970 - val_p_acc: 0.5148 - 536ms/epoch - 49ms/step
# Epoch 65/100
# 11/11 - 0s - c_loss: 1.1816 - c_acc: 0.5374 - r_acc: 0.3842 - p_loss: 1.6181 - p_acc: 0.5076 - val_p_loss: 0.8735 - val_p_acc: 0.5118 - 480ms/epoch - 44ms/step
# Epoch 66/100
# 11/11 - 1s - c_loss: 1.2271 - c_acc: 0.5147 - r_acc: 0.3885 - p_loss: 1.5712 - p_acc: 0.5106 - val_p_loss: 0.7908 - val_p_acc: 0.5059 - 517ms/epoch - 47ms/step
# Epoch 67/100
# 11/11 - 0s - c_loss: 0.9780 - c_acc: 0.5470 - r_acc: 0.3835 - p_loss: 1.6253 - p_acc: 0.5106 - val_p_loss: 0.8389 - val_p_acc: 0.5148 - 499ms/epoch - 45ms/step
# Epoch 68/100
# 11/11 - 0s - c_loss: 1.0684 - c_acc: 0.5382 - r_acc: 0.3800 - p_loss: 1.5804 - p_acc: 0.5106 - val_p_loss: 0.8043 - val_p_acc: 0.5118 - 499ms/epoch - 45ms/step
# Epoch 69/100
# 11/11 - 1s - c_loss: 1.1181 - c_acc: 0.5529 - r_acc: 0.3786 - p_loss: 1.6627 - p_acc: 0.5076 - val_p_loss: 0.9155 - val_p_acc: 0.5148 - 500ms/epoch - 45ms/step
# Epoch 70/100
# 11/11 - 0s - c_loss: 1.1740 - c_acc: 0.5602 - r_acc: 0.3700 - p_loss: 1.5902 - p_acc: 0.5046 - val_p_loss: 0.7561 - val_p_acc: 0.5148 - 486ms/epoch - 44ms/step
# Epoch 71/100
# 11/11 - 0s - c_loss: 1.1173 - c_acc: 0.5514 - r_acc: 0.3693 - p_loss: 1.6167 - p_acc: 0.5106 - val_p_loss: 0.8606 - val_p_acc: 0.5118 - 482ms/epoch - 44ms/step
# Epoch 72/100
# 11/11 - 0s - c_loss: 1.0751 - c_acc: 0.5529 - r_acc: 0.3665 - p_loss: 1.5671 - p_acc: 0.5046 - val_p_loss: 0.8081 - val_p_acc: 0.5118 - 484ms/epoch - 44ms/step
# Epoch 73/100
# 11/11 - 0s - c_loss: 0.9056 - c_acc: 0.5543 - r_acc: 0.3693 - p_loss: 1.5481 - p_acc: 0.5076 - val_p_loss: 0.8436 - val_p_acc: 0.5118 - 499ms/epoch - 45ms/step
# Epoch 74/100
# 11/11 - 1s - c_loss: 0.8408 - c_acc: 0.5455 - r_acc: 0.3700 - p_loss: 1.5756 - p_acc: 0.5046 - val_p_loss: 0.7992 - val_p_acc: 0.5118 - 510ms/epoch - 46ms/step
# Epoch 75/100
# 11/11 - 0s - c_loss: 0.9131 - c_acc: 0.5852 - r_acc: 0.3707 - p_loss: 1.5689 - p_acc: 0.5106 - val_p_loss: 0.8068 - val_p_acc: 0.5148 - 484ms/epoch - 44ms/step
# Epoch 76/100
# 11/11 - 1s - c_loss: 0.8569 - c_acc: 0.5426 - r_acc: 0.3651 - p_loss: 1.5832 - p_acc: 0.5076 - val_p_loss: 0.7463 - val_p_acc: 0.5178 - 532ms/epoch - 48ms/step
# Epoch 77/100
# 11/11 - 0s - c_loss: 1.1025 - c_acc: 0.5602 - r_acc: 0.3700 - p_loss: 1.5504 - p_acc: 0.5106 - val_p_loss: 0.8048 - val_p_acc: 0.5118 - 474ms/epoch - 43ms/step
# Epoch 78/100
# 11/11 - 0s - c_loss: 0.7507 - c_acc: 0.5573 - r_acc: 0.3707 - p_loss: 1.5865 - p_acc: 0.5076 - val_p_loss: 0.7933 - val_p_acc: 0.5118 - 468ms/epoch - 43ms/step
# Epoch 79/100
# 11/11 - 1s - c_loss: 0.9826 - c_acc: 0.5551 - r_acc: 0.3636 - p_loss: 1.5393 - p_acc: 0.5137 - val_p_loss: 0.7250 - val_p_acc: 0.5118 - 556ms/epoch - 51ms/step
# Epoch 80/100
# 11/11 - 1s - c_loss: 1.1719 - c_acc: 0.5521 - r_acc: 0.3700 - p_loss: 1.5773 - p_acc: 0.5106 - val_p_loss: 0.7442 - val_p_acc: 0.5148 - 510ms/epoch - 46ms/step
# Epoch 81/100
# 11/11 - 1s - c_loss: 1.0637 - c_acc: 0.5624 - r_acc: 0.3700 - p_loss: 1.5335 - p_acc: 0.5076 - val_p_loss: 0.7301 - val_p_acc: 0.5148 - 534ms/epoch - 49ms/step
# Epoch 82/100
# 11/11 - 1s - c_loss: 1.0024 - c_acc: 0.5609 - r_acc: 0.3636 - p_loss: 1.5316 - p_acc: 0.5076 - val_p_loss: 0.6458 - val_p_acc: 0.5118 - 518ms/epoch - 47ms/step
# Epoch 83/100
# 11/11 - 0s - c_loss: 0.9900 - c_acc: 0.5565 - r_acc: 0.3679 - p_loss: 1.5441 - p_acc: 0.5106 - val_p_loss: 0.6900 - val_p_acc: 0.5118 - 467ms/epoch - 42ms/step
# Epoch 84/100
# 11/11 - 1s - c_loss: 1.3256 - c_acc: 0.5529 - r_acc: 0.3679 - p_loss: 1.5418 - p_acc: 0.5076 - val_p_loss: 0.6174 - val_p_acc: 0.5118 - 510ms/epoch - 46ms/step
# Epoch 85/100
# 11/11 - 0s - c_loss: 0.9541 - c_acc: 0.5580 - r_acc: 0.3722 - p_loss: 1.5264 - p_acc: 0.5167 - val_p_loss: 0.7237 - val_p_acc: 0.5148 - 497ms/epoch - 45ms/step
# Epoch 86/100
# 11/11 - 1s - c_loss: 1.2467 - c_acc: 0.5742 - r_acc: 0.3693 - p_loss: 1.5026 - p_acc: 0.5137 - val_p_loss: 0.6466 - val_p_acc: 0.5089 - 510ms/epoch - 46ms/step
# Epoch 87/100
# 11/11 - 1s - c_loss: 1.0294 - c_acc: 0.5661 - r_acc: 0.3686 - p_loss: 1.4510 - p_acc: 0.5076 - val_p_loss: 0.6610 - val_p_acc: 0.5118 - 578ms/epoch - 53ms/step
# Epoch 88/100
# 11/11 - 1s - c_loss: 1.3032 - c_acc: 0.5800 - r_acc: 0.3686 - p_loss: 1.4503 - p_acc: 0.5106 - val_p_loss: 0.5952 - val_p_acc: 0.5118 - 586ms/epoch - 53ms/step
# Epoch 89/100
# 11/11 - 1s - c_loss: 1.0403 - c_acc: 0.5793 - r_acc: 0.3700 - p_loss: 1.4506 - p_acc: 0.5106 - val_p_loss: 0.6181 - val_p_acc: 0.5178 - 573ms/epoch - 52ms/step
# Epoch 90/100
# 11/11 - 1s - c_loss: 0.7017 - c_acc: 0.5433 - r_acc: 0.3722 - p_loss: 1.4662 - p_acc: 0.5046 - val_p_loss: 0.5675 - val_p_acc: 0.5207 - 534ms/epoch - 49ms/step
# Epoch 91/100
# 11/11 - 1s - c_loss: 0.8300 - c_acc: 0.5411 - r_acc: 0.3679 - p_loss: 1.4257 - p_acc: 0.5106 - val_p_loss: 0.6037 - val_p_acc: 0.5207 - 574ms/epoch - 52ms/step
# Epoch 92/100
# 11/11 - 1s - c_loss: 0.9742 - c_acc: 0.5507 - r_acc: 0.3672 - p_loss: 1.4193 - p_acc: 0.5106 - val_p_loss: 0.5668 - val_p_acc: 0.5148 - 548ms/epoch - 50ms/step
# Epoch 93/100
# 11/11 - 1s - c_loss: 1.1475 - c_acc: 0.5793 - r_acc: 0.3750 - p_loss: 1.4735 - p_acc: 0.5137 - val_p_loss: 0.6256 - val_p_acc: 0.5178 - 618ms/epoch - 56ms/step
# Epoch 94/100
# 11/11 - 1s - c_loss: 0.9978 - c_acc: 0.5661 - r_acc: 0.3707 - p_loss: 1.4232 - p_acc: 0.5076 - val_p_loss: 0.5209 - val_p_acc: 0.5089 - 583ms/epoch - 53ms/step
# Epoch 95/100
# 11/11 - 1s - c_loss: 0.7968 - c_acc: 0.5793 - r_acc: 0.3729 - p_loss: 1.4875 - p_acc: 0.5228 - val_p_loss: 0.5930 - val_p_acc: 0.5296 - 545ms/epoch - 50ms/step
# Epoch 96/100
# 11/11 - 1s - c_loss: 1.3576 - c_acc: 0.5587 - r_acc: 0.3714 - p_loss: 1.4061 - p_acc: 0.5228 - val_p_loss: 0.5208 - val_p_acc: 0.5148 - 547ms/epoch - 50ms/step
# Epoch 97/100
# 11/11 - 1s - c_loss: 0.9997 - c_acc: 0.5675 - r_acc: 0.3693 - p_loss: 1.4894 - p_acc: 0.5106 - val_p_loss: 0.5480 - val_p_acc: 0.5266 - 539ms/epoch - 49ms/step
# Epoch 98/100
# 11/11 - 1s - c_loss: 1.1258 - c_acc: 0.5609 - r_acc: 0.3729 - p_loss: 1.3996 - p_acc: 0.5046 - val_p_loss: 0.5313 - val_p_acc: 0.5237 - 613ms/epoch - 56ms/step
# Epoch 99/100
# 11/11 - 1s - c_loss: 1.0183 - c_acc: 0.5786 - r_acc: 0.3707 - p_loss: 1.5246 - p_acc: 0.5137 - val_p_loss: 0.5404 - val_p_acc: 0.5118 - 603ms/epoch - 55ms/step
# Epoch 100/100
# 11/11 - 1s - c_loss: 1.1724 - c_acc: 0.5653 - r_acc: 0.3714 - p_loss: 1.4254 - p_acc: 0.5167 - val_p_loss: 0.5101 - val_p_acc: 0.5207 - 556ms/epoch - 51ms/step

# %% [markdown]
# ### Plot the training loss and accuracy
#
# *Contrastive accuracy*: self-supervised metric, the ratio of cases in which the representation of an image is more similar to its differently augmented version's one, than to the representation of any other image in the current batch.
#
# *Correlation accuracy*: self-supervised metric, the ratio of cases in which the representation of an image is more similar to its differently augmented version's one, than to the representation of any other image in the queue.
#
# *Probe accuracy*: supervised metric, the ratio of cases in which the representation of an image is more similar to its label's one, than to the representation of any other label.

# %%
print(pretrain_history.history.keys())
# Out:
# dict_keys(['c_loss', 'c_acc', 'r_acc', 'p_loss', 'p_acc', 'val_p_loss', 'val_p_acc'])

# %%
# summarize history for loss
plt.figure(figsize=(15, 10))
# plt.plot(pretrain_history.history['c_loss'])
plt.plot(pretrain_history.history['p_loss'])
plt.plot(pretrain_history.history['val_p_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['probe_loss', 'validation_prob_loss'], loc='upper right')
plt.show()

# %%
# summarize history for accuracy
plt.figure(figsize=(15, 10))
plt.plot(pretrain_history.history['c_acc'])
plt.plot(pretrain_history.history['r_acc'])
plt.plot(pretrain_history.history['p_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['contrastive_accuracy', 'correlation_accuracy', 'probe_accuracy'], loc='upper left')
plt.show()

# %% [markdown]
# ## Plot the learned representations using UMAP
#
# Plot the representations of the labeled data in the representation space learned by the NNCLR encoder. Use UMAP to reduce the dimensionality to 2. The color of each point corresponds to its label.

# %%
import matplotlib.pyplot as plt
plt.rc('font', size=12)          # controls default text sizes
plt.rc('axes', titlesize=16)     # fontsize of the axes title
plt.rc('axes', labelsize=12)    # fontsize of the x and y labels
plt.rc('legend', fontsize=12)    # legend fontsize
plt.rc('figure', titlesize=16)  # fontsize of the figure title

# %%
# Plot the representations of the unlabeled data in the representation space learned by the NNCLR encoder. Use UMAP to reduce the dimensionality to 2. The color of each point corresponds to its label.

import umap.umap_ as umap
import numpy as np

# Get the representations of the unlabeled data.
unlabeled_feature_vectors = model.encoder(x_train, training=False)

# Reduce the dimensionality of the representations to 2.
reducer = umap.UMAP()
umap_embeddings = reducer.fit_transform(unlabeled_feature_vectors)

# Plot the representations.
plt.figure(figsize=(12, 10))
plt.scatter(umap_embeddings[:, 0], umap_embeddings[:, 1], c=y_train, s=5.0, cmap='Spectral')
# plt.gca().set_aspect('equal', 'datalim')
plt.colorbar(boundaries=np.arange(7)-0.5).set_ticks(np.arange(6))
plt.title('UMAP projection of the representations of the unlabeled data')
# Out:
# Text(0.5, 1.0, 'UMAP projection of the representations of the unlabeled data')

# %%
# Plot the representations of the labeled data in the representation space learned by the NNCLR encoder. Use UMAP to reduce the dimensionality to 2.

# Get the representations of the labeled data.
labeled_feature_vectors = model.encoder(x_validate, training=False)

# Reduce the dimensionality of the representations to 2.
# reducer = umap.UMAP()
# umap_embeddings = reducer.fit_transform(labeled_feature_vectors)
umap_embeddings = reducer.transform(labeled_feature_vectors)

# Plot the representations.
plt.figure(figsize=(12, 10))
plt.scatter(umap_embeddings[:, 0], umap_embeddings[:, 1], c=y_validate, s=5.0, cmap='Spectral')
# plt.gca().set_aspect('equal', 'datalim')
plt.colorbar(boundaries=np.arange(7)-0.5).set_ticks(np.arange(6))
plt.title('UMAP projection of the representations of the labeled data')
# Out:
# Text(0.5, 1.0, 'UMAP projection of the representations of the labeled data')

# %%
# Plot the representations of the test data in the representation space learned by the NNCLR encoder. Use UMAP to reduce the dimensionality to 2. The color of each point corresponds to its label.

# Get the representations of the test data.
test_feature_vectors = model.encoder(x_test, training=False)

# Reduce the dimensionality of the representations to 2.
# reducer = umap.UMAP()
# umap_embeddings = reducer.fit_transform(test_feature_vectors)
umap_embeddings = reducer.transform(test_feature_vectors)

# Plot the representations.
plt.figure(figsize=(12, 10))
plt.scatter(umap_embeddings[:, 0], umap_embeddings[:, 1], c=y_test, s=5.0, cmap='Spectral')
# plt.gca().set_aspect('equal', 'datalim')
plt.colorbar(boundaries=np.arange(7)-0.5).set_ticks(np.arange(6))
plt.title('UMAP projection of the representations of the test data')
# Out:
# Text(0.5, 1.0, 'UMAP projection of the representations of the test data')

# %% [markdown]
# ## Fine tune the model
#
# Fine tune the NNCLR encoder on the labeled data. The classifier is trained on the labeled data.

# %%
finetuning_model = keras.Sequential(
    [
        layers.Input(shape=input_shape),
        augmenter("classification_augmenter", input_shape=input_shape),
        model.encoder,
        layers.Dense(n_classes),
    ],
    name="finetuning_model",
)
finetuning_model.compile(
    optimizer=keras.optimizers.Adam(),
    loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=[keras.metrics.SparseCategoricalAccuracy(name="acc")],
    run_eagerly=None # True = run eagerly, False = run as graph, None = autodetect
)

finetuning_history = finetuning_model.fit(
    labeled_train_dataset, epochs=finetune_num_epochs, validation_data=test_dataset
)
# Out:
# Epoch 1/100
# 11/11 [==============================] - 2s 68ms/step - loss: 1.8921 - acc: 0.1094 - val_loss: 1.7883 - val_acc: 0.1598
# Epoch 2/100
# 11/11 [==============================] - 0s 20ms/step - loss: 1.7684 - acc: 0.1793 - val_loss: 1.7390 - val_acc: 0.2219
# Epoch 3/100
# 11/11 [==============================] - 0s 25ms/step - loss: 1.6976 - acc: 0.3556 - val_loss: 1.6506 - val_acc: 0.4438
# Epoch 4/100
# 11/11 [==============================] - 0s 22ms/step - loss: 1.5528 - acc: 0.5653 - val_loss: 1.4808 - val_acc: 0.6243
# Epoch 5/100
# 11/11 [==============================] - 0s 21ms/step - loss: 1.3324 - acc: 0.5350 - val_loss: 1.2914 - val_acc: 0.5947
# Epoch 6/100
# 11/11 [==============================] - 0s 18ms/step - loss: 1.1978 - acc: 0.5228 - val_loss: 1.1493 - val_acc: 0.5858
# Epoch 7/100
# 11/11 [==============================] - 0s 19ms/step - loss: 1.0762 - acc: 0.5684 - val_loss: 1.0199 - val_acc: 0.6746
# Epoch 8/100
# 11/11 [==============================] - 0s 20ms/step - loss: 0.9592 - acc: 0.6413 - val_loss: 0.9170 - val_acc: 0.7160
# Epoch 9/100
# 11/11 [==============================] - 0s 19ms/step - loss: 0.8726 - acc: 0.6353 - val_loss: 0.8292 - val_acc: 0.7367
# Epoch 10/100
# 11/11 [==============================] - 0s 18ms/step - loss: 0.8108 - acc: 0.6505 - val_loss: 0.7505 - val_acc: 0.7781
# Epoch 11/100
# 11/11 [==============================] - 0s 20ms/step - loss: 0.7424 - acc: 0.7173 - val_loss: 0.6868 - val_acc: 0.7870
# Epoch 12/100
# 11/11 [==============================] - 0s 17ms/step - loss: 0.6877 - acc: 0.6839 - val_loss: 0.6612 - val_acc: 0.7544
# Epoch 13/100
# 11/11 [==============================] - 0s 28ms/step - loss: 0.6887 - acc: 0.6657 - val_loss: 0.6459 - val_acc: 0.7959
# Epoch 14/100
# 11/11 [==============================] - 0s 21ms/step - loss: 0.6372 - acc: 0.7264 - val_loss: 0.6308 - val_acc: 0.7663
# Epoch 15/100
# 11/11 [==============================] - 0s 21ms/step - loss: 0.6214 - acc: 0.6900 - val_loss: 0.6877 - val_acc: 0.6775
# Epoch 16/100
# 11/11 [==============================] - 0s 18ms/step - loss: 0.6839 - acc: 0.6292 - val_loss: 0.5921 - val_acc: 0.7899
# Epoch 17/100
# 11/11 [==============================] - 0s 19ms/step - loss: 0.5986 - acc: 0.7356 - val_loss: 0.6747 - val_acc: 0.6893
# Epoch 18/100
# 11/11 [==============================] - 0s 18ms/step - loss: 0.6183 - acc: 0.7173 - val_loss: 0.6223 - val_acc: 0.7485
# Epoch 19/100
# 11/11 [==============================] - 0s 18ms/step - loss: 0.5668 - acc: 0.6960 - val_loss: 0.6935 - val_acc: 0.6805
# Epoch 20/100
# 11/11 [==============================] - 0s 18ms/step - loss: 0.6378 - acc: 0.6535 - val_loss: 0.6950 - val_acc: 0.6834
# Epoch 21/100
# 11/11 [==============================] - 0s 21ms/step - loss: 0.6311 - acc: 0.7295 - val_loss: 0.7726 - val_acc: 0.6183
# Epoch 22/100
# 11/11 [==============================] - 0s 19ms/step - loss: 0.6885 - acc: 0.6353 - val_loss: 0.6169 - val_acc: 0.7574
# Epoch 23/100
# 11/11 [==============================] - 0s 18ms/step - loss: 0.5758 - acc: 0.7112 - val_loss: 0.5865 - val_acc: 0.7959
# Epoch 24/100
# 11/11 [==============================] - 0s 18ms/step - loss: 0.5254 - acc: 0.8024 - val_loss: 0.5725 - val_acc: 0.8018
# Epoch 25/100
# 11/11 [==============================] - 0s 18ms/step - loss: 0.5148 - acc: 0.7629 - val_loss: 0.5462 - val_acc: 0.8314
# Epoch 26/100
# 11/11 [==============================] - 0s 21ms/step - loss: 0.4936 - acc: 0.7842 - val_loss: 0.5379 - val_acc: 0.8047
# Epoch 27/100
# 11/11 [==============================] - 0s 16ms/step - loss: 0.4811 - acc: 0.7872 - val_loss: 0.5102 - val_acc: 0.8107
# Epoch 28/100
# 11/11 [==============================] - 0s 16ms/step - loss: 0.4754 - acc: 0.7629 - val_loss: 0.5635 - val_acc: 0.7663
# Epoch 29/100
# 11/11 [==============================] - 0s 17ms/step - loss: 0.5323 - acc: 0.7599 - val_loss: 0.5736 - val_acc: 0.7308
# Epoch 30/100
# 11/11 [==============================] - 0s 19ms/step - loss: 0.5010 - acc: 0.7386 - val_loss: 0.6548 - val_acc: 0.7041
# Epoch 31/100
# 11/11 [==============================] - 0s 19ms/step - loss: 0.6272 - acc: 0.6687 - val_loss: 0.5588 - val_acc: 0.7426
# Epoch 32/100
# 11/11 [==============================] - 0s 17ms/step - loss: 0.5289 - acc: 0.7416 - val_loss: 0.5618 - val_acc: 0.7604
# Epoch 33/100
# 11/11 [==============================] - 0s 20ms/step - loss: 0.5091 - acc: 0.7660 - val_loss: 0.5172 - val_acc: 0.8195
# Epoch 34/100
# 11/11 [==============================] - 0s 18ms/step - loss: 0.4945 - acc: 0.7447 - val_loss: 0.5523 - val_acc: 0.7840
# Epoch 35/100
# 11/11 [==============================] - 0s 19ms/step - loss: 0.4873 - acc: 0.7812 - val_loss: 0.5381 - val_acc: 0.8254
# Epoch 36/100
# 11/11 [==============================] - 0s 18ms/step - loss: 0.4870 - acc: 0.7690 - val_loss: 0.5106 - val_acc: 0.8077
# Epoch 37/100
# 11/11 [==============================] - 0s 20ms/step - loss: 0.4404 - acc: 0.8055 - val_loss: 0.5009 - val_acc: 0.8284
# Epoch 38/100
# 11/11 [==============================] - 0s 17ms/step - loss: 0.4357 - acc: 0.7781 - val_loss: 0.5519 - val_acc: 0.7396
# Epoch 39/100
# 11/11 [==============================] - 0s 19ms/step - loss: 0.4946 - acc: 0.7508 - val_loss: 0.5324 - val_acc: 0.7929
# Epoch 40/100
# 11/11 [==============================] - 0s 19ms/step - loss: 0.4523 - acc: 0.7568 - val_loss: 0.5316 - val_acc: 0.7840
# Epoch 41/100
# 11/11 [==============================] - 0s 22ms/step - loss: 0.5146 - acc: 0.7629 - val_loss: 0.5468 - val_acc: 0.7870
# Epoch 42/100
# 11/11 [==============================] - 0s 18ms/step - loss: 0.4368 - acc: 0.7933 - val_loss: 0.5651 - val_acc: 0.7367
# Epoch 43/100
# 11/11 [==============================] - 0s 18ms/step - loss: 0.5155 - acc: 0.7356 - val_loss: 0.5205 - val_acc: 0.7840
# Epoch 44/100
# 11/11 [==============================] - 0s 18ms/step - loss: 0.4528 - acc: 0.7933 - val_loss: 0.5669 - val_acc: 0.7544
# Epoch 45/100
# 11/11 [==============================] - 0s 20ms/step - loss: 0.4949 - acc: 0.7477 - val_loss: 0.5197 - val_acc: 0.8254
# Epoch 46/100
# 11/11 [==============================] - 0s 17ms/step - loss: 0.4496 - acc: 0.7781 - val_loss: 0.5319 - val_acc: 0.7781
# Epoch 47/100
# 11/11 [==============================] - 0s 19ms/step - loss: 0.4518 - acc: 0.7903 - val_loss: 0.5334 - val_acc: 0.7899
# Epoch 48/100
# 11/11 [==============================] - 0s 19ms/step - loss: 0.4626 - acc: 0.7812 - val_loss: 0.5552 - val_acc: 0.7308
# Epoch 49/100
# 11/11 [==============================] - 0s 17ms/step - loss: 0.5151 - acc: 0.7295 - val_loss: 0.5058 - val_acc: 0.8047
# Epoch 50/100
# 11/11 [==============================] - 0s 19ms/step - loss: 0.4285 - acc: 0.7903 - val_loss: 0.5222 - val_acc: 0.8107
# Epoch 51/100
# 11/11 [==============================] - 0s 18ms/step - loss: 0.4143 - acc: 0.8237 - val_loss: 0.5322 - val_acc: 0.8343
# Epoch 52/100
# 11/11 [==============================] - 0s 20ms/step - loss: 0.4137 - acc: 0.8207 - val_loss: 0.4990 - val_acc: 0.8432
# Epoch 53/100
# 11/11 [==============================] - 0s 19ms/step - loss: 0.3772 - acc: 0.8298 - val_loss: 0.4528 - val_acc: 0.8639
# Epoch 54/100
# 11/11 [==============================] - 0s 17ms/step - loss: 0.3957 - acc: 0.8359 - val_loss: 0.4338 - val_acc: 0.8669
# Epoch 55/100
# 11/11 [==============================] - 0s 18ms/step - loss: 0.3807 - acc: 0.8328 - val_loss: 0.4624 - val_acc: 0.8254
# Epoch 56/100
# 11/11 [==============================] - 0s 24ms/step - loss: 0.3946 - acc: 0.8116 - val_loss: 0.4515 - val_acc: 0.8698
# Epoch 57/100
# 11/11 [==============================] - 0s 22ms/step - loss: 0.3796 - acc: 0.8328 - val_loss: 0.4652 - val_acc: 0.8136
# Epoch 58/100
# 11/11 [==============================] - 0s 21ms/step - loss: 0.4171 - acc: 0.8146 - val_loss: 0.5301 - val_acc: 0.8047
# Epoch 59/100
# 11/11 [==============================] - 0s 17ms/step - loss: 0.3781 - acc: 0.8116 - val_loss: 0.5056 - val_acc: 0.8107
# Epoch 60/100
# 11/11 [==============================] - 0s 17ms/step - loss: 0.4460 - acc: 0.8024 - val_loss: 0.4498 - val_acc: 0.8343
# Epoch 61/100
# 11/11 [==============================] - 0s 17ms/step - loss: 0.3948 - acc: 0.8298 - val_loss: 0.4810 - val_acc: 0.8018
# Epoch 62/100
# 11/11 [==============================] - 0s 17ms/step - loss: 0.4188 - acc: 0.7872 - val_loss: 0.5708 - val_acc: 0.7515
# Epoch 63/100
# 11/11 [==============================] - 0s 17ms/step - loss: 0.4010 - acc: 0.8146 - val_loss: 0.5328 - val_acc: 0.7781
# Epoch 64/100
# 11/11 [==============================] - 0s 18ms/step - loss: 0.4569 - acc: 0.7751 - val_loss: 0.5144 - val_acc: 0.8077
# Epoch 65/100
# 11/11 [==============================] - 0s 18ms/step - loss: 0.4200 - acc: 0.8176 - val_loss: 0.5228 - val_acc: 0.7959
# Epoch 66/100
# 11/11 [==============================] - 0s 18ms/step - loss: 0.4031 - acc: 0.8298 - val_loss: 0.5613 - val_acc: 0.8047
# Epoch 67/100
# 11/11 [==============================] - 0s 21ms/step - loss: 0.3567 - acc: 0.8298 - val_loss: 0.4879 - val_acc: 0.8136
# Epoch 68/100
# 11/11 [==============================] - 0s 18ms/step - loss: 0.3603 - acc: 0.8389 - val_loss: 0.5330 - val_acc: 0.7840
# Epoch 69/100
# 11/11 [==============================] - 0s 17ms/step - loss: 0.4068 - acc: 0.8176 - val_loss: 0.5379 - val_acc: 0.7633
# Epoch 70/100
# 11/11 [==============================] - 0s 17ms/step - loss: 0.4418 - acc: 0.7872 - val_loss: 0.4522 - val_acc: 0.8314
# Epoch 71/100
# 11/11 [==============================] - 0s 16ms/step - loss: 0.3880 - acc: 0.8419 - val_loss: 0.5206 - val_acc: 0.7692
# Epoch 72/100
# 11/11 [==============================] - 0s 20ms/step - loss: 0.4068 - acc: 0.8359 - val_loss: 0.6307 - val_acc: 0.7633
# Epoch 73/100
# 11/11 [==============================] - 0s 17ms/step - loss: 0.3465 - acc: 0.8450 - val_loss: 0.4987 - val_acc: 0.7988
# Epoch 74/100
# 11/11 [==============================] - 0s 19ms/step - loss: 0.3624 - acc: 0.8602 - val_loss: 0.5510 - val_acc: 0.7959
# Epoch 75/100
# 11/11 [==============================] - 0s 19ms/step - loss: 0.3190 - acc: 0.8815 - val_loss: 0.4496 - val_acc: 0.8314
# Epoch 76/100
# 11/11 [==============================] - 0s 19ms/step - loss: 0.3070 - acc: 0.8784 - val_loss: 0.4944 - val_acc: 0.7840
# Epoch 77/100
# 11/11 [==============================] - 0s 19ms/step - loss: 0.2992 - acc: 0.8571 - val_loss: 0.4412 - val_acc: 0.8698
# Epoch 78/100
# 11/11 [==============================] - 0s 19ms/step - loss: 0.3333 - acc: 0.8511 - val_loss: 0.5534 - val_acc: 0.7663
# Epoch 79/100
# 11/11 [==============================] - 0s 21ms/step - loss: 0.2910 - acc: 0.8784 - val_loss: 0.5580 - val_acc: 0.7663
# Epoch 80/100
# 11/11 [==============================] - 0s 18ms/step - loss: 0.3127 - acc: 0.8450 - val_loss: 0.5137 - val_acc: 0.7870
# Epoch 81/100
# 11/11 [==============================] - 0s 19ms/step - loss: 0.2760 - acc: 0.8936 - val_loss: 0.4519 - val_acc: 0.8550
# Epoch 82/100
# 11/11 [==============================] - 0s 19ms/step - loss: 0.2958 - acc: 0.8693 - val_loss: 0.4636 - val_acc: 0.8018
# Epoch 83/100
# 11/11 [==============================] - 0s 19ms/step - loss: 0.3226 - acc: 0.8723 - val_loss: 0.4440 - val_acc: 0.8402
# Epoch 84/100
# 11/11 [==============================] - 0s 22ms/step - loss: 0.2733 - acc: 0.8875 - val_loss: 0.4598 - val_acc: 0.8343
# Epoch 85/100
# 11/11 [==============================] - 0s 19ms/step - loss: 0.2912 - acc: 0.8602 - val_loss: 0.4884 - val_acc: 0.7929
# Epoch 86/100
# 11/11 [==============================] - 0s 18ms/step - loss: 0.3103 - acc: 0.8632 - val_loss: 0.4375 - val_acc: 0.8373
# Epoch 87/100
# 11/11 [==============================] - 0s 27ms/step - loss: 0.2926 - acc: 0.8663 - val_loss: 0.3942 - val_acc: 0.8639
# Epoch 88/100
# 11/11 [==============================] - 0s 20ms/step - loss: 0.2775 - acc: 0.8906 - val_loss: 0.4839 - val_acc: 0.8018
# Epoch 89/100
# 11/11 [==============================] - 0s 21ms/step - loss: 0.3552 - acc: 0.8511 - val_loss: 0.6579 - val_acc: 0.7426
# Epoch 90/100
# 11/11 [==============================] - 0s 21ms/step - loss: 0.2701 - acc: 0.8602 - val_loss: 0.5617 - val_acc: 0.7840
# Epoch 91/100
# 11/11 [==============================] - 0s 20ms/step - loss: 0.3958 - acc: 0.8267 - val_loss: 0.6909 - val_acc: 0.6686
# Epoch 92/100
# 11/11 [==============================] - 0s 23ms/step - loss: 0.4235 - acc: 0.8085 - val_loss: 0.7065 - val_acc: 0.7426
# Epoch 93/100
# 11/11 [==============================] - 0s 20ms/step - loss: 0.6034 - acc: 0.7204 - val_loss: 0.4269 - val_acc: 0.8817
# Epoch 94/100
# 11/11 [==============================] - 0s 25ms/step - loss: 0.3516 - acc: 0.8541 - val_loss: 0.4794 - val_acc: 0.8136
# Epoch 95/100
# 11/11 [==============================] - 0s 27ms/step - loss: 0.3184 - acc: 0.8815 - val_loss: 0.4524 - val_acc: 0.8521
# Epoch 96/100
# 11/11 [==============================] - 0s 21ms/step - loss: 0.2800 - acc: 0.8967 - val_loss: 0.4843 - val_acc: 0.8284
# Epoch 97/100
# 11/11 [==============================] - 0s 19ms/step - loss: 0.2471 - acc: 0.9331 - val_loss: 0.4475 - val_acc: 0.8550
# Epoch 98/100
# 11/11 [==============================] - 0s 20ms/step - loss: 0.2447 - acc: 0.8997 - val_loss: 0.4244 - val_acc: 0.8491
# Epoch 99/100
# 11/11 [==============================] - 0s 20ms/step - loss: 0.2626 - acc: 0.8875 - val_loss: 0.5360 - val_acc: 0.7811
# Epoch 100/100
# 11/11 [==============================] - 0s 22ms/step - loss: 0.2633 - acc: 0.9027 - val_loss: 0.5082 - val_acc: 0.8314

# %% [markdown]
# ### Plot the fine-tuning loss and accuracy

# %%
# summarize history for loss

plt.plot(finetuning_history.history['loss'])
plt.plot(finetuning_history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train_loss', 'test_loss'], loc='upper right')
plt.show()

# %%
# summarize history for accuracy
plt.plot(finetuning_history.history['acc'])
plt.plot(finetuning_history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train_accuracy', 'test_accuracy'], loc='upper left')
plt.show()

# %% [markdown]
# ## Evaluate our fine tuned model on the test set

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
import pandas as pd
import seaborn as sns
import numpy as np

t_names = ['Downstairs', 'Jogging', 'Sitting', 'Standing', 'Upstairs', 'Walking']

#### Show results
predictions = finetuning_model.predict(test_dataset, verbose=0, batch_size=32)
#must use values not one-hot encoding, use argmax to convert
y_pred = np.argmax(predictions, axis=-1) # axis=-1 means last axis
y_test = np.concatenate([y for x, y in test_dataset], axis=0)
print('Prediction accuracy: {0:.3f}'.format(accuracy_score(y_test, y_pred)))

print(classification_report(y_test, y_pred, target_names=t_names))
cm = confusion_matrix(y_test, y_pred)
print(cm)
cm_df = pd.DataFrame(cm,
                     index = t_names, 
                     columns = t_names)
fig = plt.figure(figsize=(6.5,5))
sns.heatmap(cm_df, annot=True, fmt='d', cmap='cubehelix_r')
plt.title('1D CNN using e4_Nov2019'+'\nAccuracy:{0:.3f}'.format(accuracy_score(y_test, y_pred)))
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.tight_layout() # keeps labels from being cutoff when saving as pdf
plt.show()
# Out:
# Prediction accuracy: 0.790
#               precision    recall  f1-score   support
#
#   Downstairs       0.90      0.76      0.82        49
#      Jogging       1.00      0.98      0.99        58
#      Sitting       1.00      0.38      0.55        61
#     Standing       0.60      1.00      0.75        58
#     Upstairs       0.69      0.71      0.70        52
#      Walking       0.82      0.92      0.87        60
#
#     accuracy                           0.79       338
#    macro avg       0.84      0.79      0.78       338
# weighted avg       0.84      0.79      0.78       338
#
# [[37  0  0  0 12  0]
#  [ 0 57  0  0  0  1]
#  [ 0  0 23 38  0  0]
#  [ 0  0  0 58  0  0]
#  [ 4  0  0  0 37 11]
#  [ 0  0  0  0  5 55]]

# %% [markdown]
# ## Evaluate the learned representations using a KNN classifier

# %%
from sklearn.neighbors import KNeighborsClassifier

# Convert train dataset to feature vectors using the self-supervised encoder
train_feature_vectors = model.encoder(x_train, training=False)

knn = KNeighborsClassifier(n_neighbors=3)
knn_model = knn.fit(train_feature_vectors, y_train)

# Predict test set with the knn model
test_feature_vectors = model.encoder(x_test, training=False)
y_pred = knn_model.predict(test_feature_vectors)

print('Prediction accuracy: {0:.3f}'.format(accuracy_score(y_test, y_pred)))
print(classification_report(y_test, y_pred, target_names=t_names))
cm = confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# Prediction accuracy: 0.917
#               precision    recall  f1-score   support
#
#   Downstairs       0.89      0.86      0.88        49
#      Jogging       0.96      0.95      0.96        58
#      Sitting       0.98      0.98      0.98        61
#     Standing       0.98      0.98      0.98        58
#     Upstairs       0.80      0.85      0.82        52
#      Walking       0.87      0.87      0.87        60
#
#     accuracy                           0.92       338
#    macro avg       0.92      0.91      0.91       338
# weighted avg       0.92      0.92      0.92       338
#
# [[42  0  0  0  6  1]
#  [ 1 55  0  0  1  1]
#  [ 0  0 60  1  0  0]
#  [ 0  0  1 57  0  0]
#  [ 2  0  0  0 44  6]
#  [ 2  2  0  0  4 52]]
