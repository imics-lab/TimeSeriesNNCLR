# %% [markdown]
# # NNCLR example

# %% [markdown]
# ## Imports

# %%
import matplotlib.pyplot as plt
import tensorflow as tf
# import tensorflow_datasets as tfds
from tensorflow import keras
from tensorflow.keras import layers

from data_loader import load_e4_dataset
from augmentations import *
from encoder import encoder
from nnclr import NNCLR 

# %matplotlib inline

# %% [markdown]
# ## Set configuration parameters

# %%
### Hyperparameters
try:
    AUTOTUNE = tf.data.AUTOTUNE     
except:
    AUTOTUNE = tf.data.experimental.AUTOTUNE

temperature = 0.1        # the temperature for the softmax function in the contrastive loss
queue_size = 1000        # the size of the queue for storing the feature vectors

width = 64                  # the size of the output embedding vector for each sequence
pretrain_num_epochs = 100   # the number of epochs to pretrain the model
finetune_num_epochs = 100    # The number of epochs to fine-tune the model.
BATCH_SIZE = 16             # the batch size for training
SHUFFLE_BUFFER_SIZE = 1000  # the buffer size for shuffling the dataset
k_size = 16                 # the size of the kernel for the 1D convolutional layer in the encoder
n_classes = 6               # the number of classes in the dataset

t_names = ['Downstairs', 'Jogging', 'Sitting', 'Standing', 'Upstairs', 'Walking']

# %% [markdown]
# ## Load the data
#
# NNCLR takes in both the unlabeled and labeled data. The self-supervised encoder is trained on both the labeled and unlabeled data. The labeled data is used to train the classifier.

# %%
(batch_size, train_dataset, unlabeled_train_dataset, labeled_train_dataset, test_dataset, 
    x_train, y_train, x_validate, y_validate, x_test, y_test) = load_e4_dataset()
# Out:
# Processing  1574621345_A01F11.zip
# Unzipping e4 file in local directory c:\Users\vangelis\Files\Academia\Research\DeepLearning\Self-Supervised-Learning\NNCLR_keras\TimeSeriesNNCLR/temp
# c:\Users\vangelis\Files\Academia\Research\DeepLearning\Self-Supervised-Learning\NNCLR_keras\TimeSeriesNNCLR/temp/ACC.csv Sample frequency =  32.0  Hz
# File start time =  Sun, 24 Nov 2019 12:49:05
# File end time   =  Sun, 24 Nov 2019 12:58:11
# Tag info (button presses) from tags.csv
#     UTC_time          Local Time
# 0 1574621375.17 Sun, 24 Nov 2019 12:49:35
# 1 1574621774.22 Sun, 24 Nov 2019 12:56:14
# Warning: Multiple subjects detected in csv, unusual for e4 data.
# Label Counts
#  label
# Upstairs      6208
# Downstairs    5889
# Undefined     5405
# Name: count, dtype: int64
# No NaN entries found
# shapes call broke when making the function - not sure why
# Processing  1574622389_A01F11.zip
# Unzipping e4 file in local directory c:\Users\vangelis\Files\Academia\Research\DeepLearning\Self-Supervised-Learning\NNCLR_keras\TimeSeriesNNCLR/temp
# c:\Users\vangelis\Files\Academia\Research\DeepLearning\Self-Supervised-Learning\NNCLR_keras\TimeSeriesNNCLR/temp/ACC.csv Sample frequency =  32.0  Hz
# File start time =  Sun, 24 Nov 2019 13:06:29
# File end time   =  Sun, 24 Nov 2019 13:15:03
# Tag info (button presses) from tags.csv
#     UTC_time          Local Time
# 0 1574622432.21 Sun, 24 Nov 2019 13:07:12
# 1 1574622822.72 Sun, 24 Nov 2019 13:13:42
# Warning: Multiple subjects detected in csv, unusual for e4 data.
# Label Counts
#  label
# Walking      5793
# Jogging      5792
# Undefined    4885
# Name: count, dtype: int64
# No NaN entries found
# shapes call broke when making the function - not sure why
# Processing  1574624998_A01F11.zip
# Unzipping e4 file in local directory c:\Users\vangelis\Files\Academia\Research\DeepLearning\Self-Supervised-Learning\NNCLR_keras\TimeSeriesNNCLR/temp
# c:\Users\vangelis\Files\Academia\Research\DeepLearning\Self-Supervised-Learning\NNCLR_keras\TimeSeriesNNCLR/temp/ACC.csv Sample frequency =  32.0  Hz
# File start time =  Sun, 24 Nov 2019 13:49:58
# File end time   =  Sun, 24 Nov 2019 13:57:15
# Tag info (button presses) from tags.csv
#     UTC_time          Local Time
# 0 1574625042.71 Sun, 24 Nov 2019 13:50:42
# 1 1574625419.43 Sun, 24 Nov 2019 13:56:59
# Warning: Multiple subjects detected in csv, unusual for e4 data.
# Label Counts
#  label
# Sitting      5857
# Standing     5632
# Undefined    2503
# Name: count, dtype: int64
# No NaN entries found
# shapes call broke when making the function - not sure why
# shapes call broke when making the function - not sure why
# Final Label Counts
# [['Downstairs' '170']
#  ['Jogging' '175']
#  ['Sitting' '177']
#  ['Standing' '170']
#  ['Upstairs' '180']
#  ['Walking' '175']]
# e4 November 2019 zip files
# 1574621345_A01F11.zip 1574622389_A01F11.zip 1574624998_A01F11.zip
# Time steps =96, Step =32, no resample
# Final Shapes
# shapes call broke when making the function - not sure why
# Not one-hot-encoding
# {'Downstairs': 0, 'Jogging': 1, 'Sitting': 2, 'Standing': 3, 'Upstairs': 4, 'Walking': 5}
# x_train shape: (380, 96, 4)
# y_train shape: (380,)
# x_validate shape: (329, 96, 4)
# y_validate shape: (329,)
# x_test shape: (338, 96, 4)
# y_test shape: (338,)

# %%
print("x_train shape:", x_train.shape)
print("y_train shape:", y_train.shape)
print("x_validate shape:", x_validate.shape)
print("y_validate shape:", y_validate.shape)
print("x_test shape:", x_test.shape)
print("y_test shape:", y_test.shape)
# Out:
# x_train shape: (380, 96, 4)
# y_train shape: (380,)
# x_validate shape: (329, 96, 4)
# y_validate shape: (329,)
# x_test shape: (338, 96, 4)
# y_test shape: (338,)

# %% [markdown]
# ## Pre-train NNCLR

# %% [markdown]
# ### Specify the encoder

# %%
input_shape = x_train[0].shape # Get the shape from the first element of the training set

# Create the encoder model
encoder_model = keras.Sequential(
		[
			keras.Input(shape=input_shape),
			layers.Conv1D(filters=100, kernel_size=9, activation='relu'),
			layers.Conv1D(filters=100, kernel_size=9, activation='relu'),
			layers.Dropout(0.5),
			layers.MaxPooling1D(pool_size=2),
			layers.Flatten(),
			layers.Dense(width, activation='relu')
   		],
        name="encoder_model",
    )
encoder_model.summary()
# Out:
# Model: "encoder_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_2 (Conv1D)           (None, 88, 100)           3700
#
#  conv1d_3 (Conv1D)           (None, 80, 100)           90100
#
#  dropout_1 (Dropout)         (None, 80, 100)           0
#
#  max_pooling1d_1 (MaxPoolin  (None, 40, 100)           0
#  g1D)
#
#  flatten_1 (Flatten)         (None, 4000)              0
#
#  dense_2 (Dense)             (None, 64)                256064
#
# =================================================================
# Total params: 349864 (1.33 MB)
# Trainable params: 349864 (1.33 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model = NNCLR(temperature=temperature, queue_size=queue_size, input_shape=input_shape, output_width=width, n_classes= n_classes, encoder=encoder_model)

model.compile(
    contrastive_optimizer=keras.optimizers.Adam(),
    probe_optimizer=keras.optimizers.Adam(),
    run_eagerly=None # True = run eagerly, False = run as graph, None = autodetect
)

model.build(input_shape=(None, input_shape[0], input_shape[1]))
model.summary()
# Out:
# Model: "nnclr"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  contrastive_augmenter (Seq  (None, None, 4)           0
#  uential)
#
#  classification_augmenter (  (None, None, 4)           0
#  Sequential)
#
#  encoder_model (Sequential)  (None, 64)                349864
#
#  projection_head (Sequentia  (None, 64)                8320
#  l)
#
#  linear_probe (Sequential)   (None, 6)                 390
#
# =================================================================
# Total params: 422580 (1.61 MB)
# Trainable params: 358574 (1.37 MB)
# Non-trainable params: 64006 (250.02 KB)
# _________________________________________________________________

# %%
pretrain_history = model.fit(
    train_dataset, epochs=pretrain_num_epochs, validation_data=test_dataset, 
    verbose=2 # 0 = silent, 1 = progress bar, 2 = one line per epoch, 3 = one line per batch
              # Due to a weird bug, the fit function crashes if verbose is set to 1.
)
# Out:
# Epoch 1/100
# 21/21 - 5s - c_loss: 3.2121 - c_acc: 0.0526 - r_acc: 0.0387 - p_loss: 1.9254 - p_acc: 0.1489 - val_p_loss: 1.9231 - val_p_acc: 0.1538 - 5s/epoch - 220ms/step
# Epoch 2/100
# 21/21 - 1s - c_loss: 3.1487 - c_acc: 0.1053 - r_acc: 0.0774 - p_loss: 1.8178 - p_acc: 0.1550 - val_p_loss: 1.8358 - val_p_acc: 0.1538 - 617ms/epoch - 29ms/step
# Epoch 3/100
# 21/21 - 1s - c_loss: 2.1019 - c_acc: 0.2722 - r_acc: 0.2418 - p_loss: 1.7831 - p_acc: 0.1581 - val_p_loss: 1.8769 - val_p_acc: 0.1509 - 565ms/epoch - 27ms/step
# Epoch 4/100
# 21/21 - 1s - c_loss: 1.7728 - c_acc: 0.3579 - r_acc: 0.3103 - p_loss: 1.7661 - p_acc: 0.1550 - val_p_loss: 1.8627 - val_p_acc: 0.1302 - 554ms/epoch - 26ms/step
# Epoch 5/100
# 21/21 - 1s - c_loss: 1.5781 - c_acc: 0.3782 - r_acc: 0.3140 - p_loss: 1.7765 - p_acc: 0.1246 - val_p_loss: 1.8775 - val_p_acc: 0.1627 - 544ms/epoch - 26ms/step
# Epoch 6/100
# 21/21 - 1s - c_loss: 1.4999 - c_acc: 0.4188 - r_acc: 0.3419 - p_loss: 1.8035 - p_acc: 0.1915 - val_p_loss: 1.8789 - val_p_acc: 0.2101 - 573ms/epoch - 27ms/step
# Epoch 7/100
# 21/21 - 1s - c_loss: 1.3728 - c_acc: 0.4180 - r_acc: 0.3393 - p_loss: 1.7986 - p_acc: 0.1581 - val_p_loss: 1.8868 - val_p_acc: 0.2130 - 541ms/epoch - 26ms/step
# Epoch 8/100
# 21/21 - 1s - c_loss: 1.5083 - c_acc: 0.4421 - r_acc: 0.3504 - p_loss: 1.7891 - p_acc: 0.2310 - val_p_loss: 1.8834 - val_p_acc: 0.1893 - 549ms/epoch - 26ms/step
# Epoch 9/100
# 21/21 - 1s - c_loss: 1.6789 - c_acc: 0.4511 - r_acc: 0.3557 - p_loss: 1.8000 - p_acc: 0.2036 - val_p_loss: 1.8818 - val_p_acc: 0.2041 - 534ms/epoch - 25ms/step
# Epoch 10/100
# 21/21 - 1s - c_loss: 1.4495 - c_acc: 0.4774 - r_acc: 0.3717 - p_loss: 1.8053 - p_acc: 0.2432 - val_p_loss: 1.8764 - val_p_acc: 0.2189 - 514ms/epoch - 24ms/step
# Epoch 11/100
# 21/21 - 1s - c_loss: 1.3685 - c_acc: 0.4489 - r_acc: 0.3512 - p_loss: 1.8022 - p_acc: 0.2128 - val_p_loss: 1.8891 - val_p_acc: 0.2071 - 619ms/epoch - 29ms/step
# Epoch 12/100
# 21/21 - 1s - c_loss: 1.6241 - c_acc: 0.4842 - r_acc: 0.3687 - p_loss: 1.7991 - p_acc: 0.2036 - val_p_loss: 1.8876 - val_p_acc: 0.1864 - 532ms/epoch - 25ms/step
# Epoch 13/100
# 21/21 - 1s - c_loss: 1.5089 - c_acc: 0.4496 - r_acc: 0.3612 - p_loss: 1.8069 - p_acc: 0.2067 - val_p_loss: 1.9043 - val_p_acc: 0.1893 - 528ms/epoch - 25ms/step
# Epoch 14/100
# 21/21 - 1s - c_loss: 1.2172 - c_acc: 0.4827 - r_acc: 0.3743 - p_loss: 1.7846 - p_acc: 0.2006 - val_p_loss: 1.8810 - val_p_acc: 0.2308 - 533ms/epoch - 25ms/step
# Epoch 15/100
# 21/21 - 1s - c_loss: 1.3014 - c_acc: 0.4744 - r_acc: 0.3850 - p_loss: 1.8011 - p_acc: 0.2158 - val_p_loss: 1.8843 - val_p_acc: 0.2160 - 554ms/epoch - 26ms/step
# Epoch 16/100
# 21/21 - 1s - c_loss: 1.4672 - c_acc: 0.4872 - r_acc: 0.3739 - p_loss: 1.8071 - p_acc: 0.2006 - val_p_loss: 1.8499 - val_p_acc: 0.2041 - 526ms/epoch - 25ms/step
# Epoch 17/100
# 21/21 - 1s - c_loss: 1.1564 - c_acc: 0.4872 - r_acc: 0.3798 - p_loss: 1.8048 - p_acc: 0.1915 - val_p_loss: 1.8708 - val_p_acc: 0.1716 - 513ms/epoch - 24ms/step
# Epoch 18/100
# 21/21 - 1s - c_loss: 1.4771 - c_acc: 0.4887 - r_acc: 0.3757 - p_loss: 1.8063 - p_acc: 0.1884 - val_p_loss: 1.8806 - val_p_acc: 0.1746 - 535ms/epoch - 25ms/step
# Epoch 19/100
# 21/21 - 1s - c_loss: 1.5783 - c_acc: 0.4722 - r_acc: 0.3735 - p_loss: 1.7971 - p_acc: 0.1763 - val_p_loss: 1.8451 - val_p_acc: 0.1805 - 584ms/epoch - 28ms/step
# Epoch 20/100
# 21/21 - 1s - c_loss: 1.0272 - c_acc: 0.5120 - r_acc: 0.3850 - p_loss: 1.7892 - p_acc: 0.1733 - val_p_loss: 1.8501 - val_p_acc: 0.1805 - 631ms/epoch - 30ms/step
# Epoch 21/100
# 21/21 - 1s - c_loss: 1.2244 - c_acc: 0.4729 - r_acc: 0.3772 - p_loss: 1.7853 - p_acc: 0.1733 - val_p_loss: 1.8357 - val_p_acc: 0.1805 - 527ms/epoch - 25ms/step
# Epoch 22/100
# 21/21 - 1s - c_loss: 1.2803 - c_acc: 0.4947 - r_acc: 0.3761 - p_loss: 1.7791 - p_acc: 0.3070 - val_p_loss: 1.8243 - val_p_acc: 0.2929 - 519ms/epoch - 25ms/step
# Epoch 23/100
# 21/21 - 1s - c_loss: 1.1901 - c_acc: 0.5436 - r_acc: 0.3813 - p_loss: 1.7733 - p_acc: 0.3009 - val_p_loss: 1.8159 - val_p_acc: 0.3077 - 516ms/epoch - 25ms/step
# Epoch 24/100
# 21/21 - 1s - c_loss: 1.2871 - c_acc: 0.5203 - r_acc: 0.3858 - p_loss: 1.7817 - p_acc: 0.2219 - val_p_loss: 1.7855 - val_p_acc: 0.2811 - 572ms/epoch - 27ms/step
# Epoch 25/100
# 21/21 - 1s - c_loss: 1.4517 - c_acc: 0.5180 - r_acc: 0.3821 - p_loss: 1.7561 - p_acc: 0.3313 - val_p_loss: 1.7591 - val_p_acc: 0.3462 - 553ms/epoch - 26ms/step
# Epoch 26/100
# 21/21 - 1s - c_loss: 1.2628 - c_acc: 0.5150 - r_acc: 0.3876 - p_loss: 1.7620 - p_acc: 0.3374 - val_p_loss: 1.7246 - val_p_acc: 0.3669 - 527ms/epoch - 25ms/step
# Epoch 27/100
# 21/21 - 1s - c_loss: 1.3207 - c_acc: 0.5211 - r_acc: 0.3899 - p_loss: 1.7483 - p_acc: 0.3435 - val_p_loss: 1.7291 - val_p_acc: 0.3521 - 535ms/epoch - 25ms/step
# Epoch 28/100
# 21/21 - 1s - c_loss: 1.0635 - c_acc: 0.5090 - r_acc: 0.3865 - p_loss: 1.7481 - p_acc: 0.3343 - val_p_loss: 1.7023 - val_p_acc: 0.3639 - 531ms/epoch - 25ms/step
# Epoch 29/100
# 21/21 - 1s - c_loss: 1.1905 - c_acc: 0.5526 - r_acc: 0.3884 - p_loss: 1.7569 - p_acc: 0.3435 - val_p_loss: 1.7359 - val_p_acc: 0.3521 - 533ms/epoch - 25ms/step
# Epoch 30/100
# 21/21 - 1s - c_loss: 1.0382 - c_acc: 0.5549 - r_acc: 0.3776 - p_loss: 1.7547 - p_acc: 0.3435 - val_p_loss: 1.7085 - val_p_acc: 0.3521 - 525ms/epoch - 25ms/step
# Epoch 31/100
# 21/21 - 1s - c_loss: 1.4570 - c_acc: 0.5504 - r_acc: 0.3925 - p_loss: 1.7679 - p_acc: 0.3435 - val_p_loss: 1.6742 - val_p_acc: 0.3402 - 517ms/epoch - 25ms/step
# Epoch 32/100
# 21/21 - 1s - c_loss: 1.2481 - c_acc: 0.5602 - r_acc: 0.3876 - p_loss: 1.7462 - p_acc: 0.3617 - val_p_loss: 1.6319 - val_p_acc: 0.3639 - 521ms/epoch - 25ms/step
# Epoch 33/100
# 21/21 - 1s - c_loss: 0.9886 - c_acc: 0.5564 - r_acc: 0.4010 - p_loss: 1.7014 - p_acc: 0.3435 - val_p_loss: 1.6123 - val_p_acc: 0.3935 - 529ms/epoch - 25ms/step
# Epoch 34/100
# 21/21 - 1s - c_loss: 0.9994 - c_acc: 0.5887 - r_acc: 0.3910 - p_loss: 1.7420 - p_acc: 0.3495 - val_p_loss: 1.5617 - val_p_acc: 0.3580 - 543ms/epoch - 26ms/step
# Epoch 35/100
# 21/21 - 1s - c_loss: 1.2564 - c_acc: 0.5805 - r_acc: 0.3914 - p_loss: 1.6903 - p_acc: 0.3374 - val_p_loss: 1.5276 - val_p_acc: 0.3609 - 533ms/epoch - 25ms/step
# Epoch 36/100
# 21/21 - 1s - c_loss: 1.1818 - c_acc: 0.5684 - r_acc: 0.3910 - p_loss: 1.8031 - p_acc: 0.3526 - val_p_loss: 1.4815 - val_p_acc: 0.3373 - 532ms/epoch - 25ms/step
# Epoch 37/100
# 21/21 - 1s - c_loss: 1.2096 - c_acc: 0.6045 - r_acc: 0.3984 - p_loss: 1.7202 - p_acc: 0.3526 - val_p_loss: 1.4462 - val_p_acc: 0.3728 - 600ms/epoch - 29ms/step
# Epoch 38/100
# 21/21 - 1s - c_loss: 0.9592 - c_acc: 0.5872 - r_acc: 0.3973 - p_loss: 1.7777 - p_acc: 0.3465 - val_p_loss: 1.4068 - val_p_acc: 0.3580 - 536ms/epoch - 26ms/step
# Epoch 39/100
# 21/21 - 1s - c_loss: 0.9944 - c_acc: 0.6045 - r_acc: 0.3940 - p_loss: 1.7428 - p_acc: 0.3739 - val_p_loss: 1.3833 - val_p_acc: 0.3698 - 586ms/epoch - 28ms/step
# Epoch 40/100
# 21/21 - 1s - c_loss: 1.2615 - c_acc: 0.6000 - r_acc: 0.4100 - p_loss: 1.6583 - p_acc: 0.3556 - val_p_loss: 1.4302 - val_p_acc: 0.3432 - 520ms/epoch - 25ms/step
# Epoch 41/100
# 21/21 - 1s - c_loss: 0.9050 - c_acc: 0.5827 - r_acc: 0.3917 - p_loss: 1.7194 - p_acc: 0.3404 - val_p_loss: 1.3933 - val_p_acc: 0.3639 - 517ms/epoch - 25ms/step
# Epoch 42/100
# 21/21 - 1s - c_loss: 0.9372 - c_acc: 0.6068 - r_acc: 0.4040 - p_loss: 1.7731 - p_acc: 0.3708 - val_p_loss: 1.2958 - val_p_acc: 0.4467 - 517ms/epoch - 25ms/step
# Epoch 43/100
# 21/21 - 1s - c_loss: 0.8774 - c_acc: 0.6226 - r_acc: 0.4133 - p_loss: 1.8127 - p_acc: 0.3860 - val_p_loss: 1.2539 - val_p_acc: 0.3550 - 535ms/epoch - 25ms/step
# Epoch 44/100
# 21/21 - 1s - c_loss: 1.0445 - c_acc: 0.6165 - r_acc: 0.4085 - p_loss: 1.7336 - p_acc: 0.3739 - val_p_loss: 1.2467 - val_p_acc: 0.3757 - 538ms/epoch - 26ms/step
# Epoch 45/100
# 21/21 - 1s - c_loss: 0.9691 - c_acc: 0.6113 - r_acc: 0.4141 - p_loss: 1.6750 - p_acc: 0.4255 - val_p_loss: 1.2329 - val_p_acc: 0.4763 - 517ms/epoch - 25ms/step
# Epoch 46/100
# 21/21 - 1s - c_loss: 1.0043 - c_acc: 0.6173 - r_acc: 0.4230 - p_loss: 1.6789 - p_acc: 0.4468 - val_p_loss: 1.1309 - val_p_acc: 0.5059 - 532ms/epoch - 25ms/step
# Epoch 47/100
# 21/21 - 1s - c_loss: 1.0981 - c_acc: 0.6090 - r_acc: 0.4178 - p_loss: 1.6746 - p_acc: 0.5167 - val_p_loss: 1.1940 - val_p_acc: 0.5089 - 519ms/epoch - 25ms/step
# Epoch 48/100
# 21/21 - 1s - c_loss: 1.3412 - c_acc: 0.6233 - r_acc: 0.4107 - p_loss: 1.6292 - p_acc: 0.4863 - val_p_loss: 1.1323 - val_p_acc: 0.4852 - 564ms/epoch - 27ms/step
# Epoch 49/100
# 21/21 - 1s - c_loss: 0.8476 - c_acc: 0.6120 - r_acc: 0.4148 - p_loss: 1.6413 - p_acc: 0.4438 - val_p_loss: 1.1317 - val_p_acc: 0.5473 - 528ms/epoch - 25ms/step
# Epoch 50/100
# 21/21 - 1s - c_loss: 0.9981 - c_acc: 0.6248 - r_acc: 0.4193 - p_loss: 1.6920 - p_acc: 0.5167 - val_p_loss: 1.1901 - val_p_acc: 0.5296 - 585ms/epoch - 28ms/step
# Epoch 51/100
# 21/21 - 1s - c_loss: 0.8328 - c_acc: 0.6271 - r_acc: 0.4144 - p_loss: 1.6770 - p_acc: 0.5167 - val_p_loss: 1.0666 - val_p_acc: 0.5237 - 548ms/epoch - 26ms/step
# Epoch 52/100
# 21/21 - 1s - c_loss: 0.9287 - c_acc: 0.6060 - r_acc: 0.4215 - p_loss: 1.7506 - p_acc: 0.5167 - val_p_loss: 0.9463 - val_p_acc: 0.5444 - 539ms/epoch - 26ms/step
# Epoch 53/100
# 21/21 - 1s - c_loss: 1.0986 - c_acc: 0.5925 - r_acc: 0.4182 - p_loss: 1.6654 - p_acc: 0.5228 - val_p_loss: 0.9983 - val_p_acc: 0.5325 - 562ms/epoch - 27ms/step
# Epoch 54/100
# 21/21 - 1s - c_loss: 1.0705 - c_acc: 0.6278 - r_acc: 0.4118 - p_loss: 1.7207 - p_acc: 0.5319 - val_p_loss: 0.8667 - val_p_acc: 0.5325 - 515ms/epoch - 25ms/step
# Epoch 55/100
# 21/21 - 1s - c_loss: 0.9937 - c_acc: 0.6233 - r_acc: 0.4174 - p_loss: 1.7608 - p_acc: 0.5228 - val_p_loss: 0.7398 - val_p_acc: 0.5355 - 531ms/epoch - 25ms/step
# Epoch 56/100
# 21/21 - 1s - c_loss: 0.9368 - c_acc: 0.6361 - r_acc: 0.4167 - p_loss: 1.6370 - p_acc: 0.5167 - val_p_loss: 0.6844 - val_p_acc: 0.5414 - 533ms/epoch - 25ms/step
# Epoch 57/100
# 21/21 - 1s - c_loss: 0.6317 - c_acc: 0.6489 - r_acc: 0.4226 - p_loss: 1.7213 - p_acc: 0.5319 - val_p_loss: 0.7938 - val_p_acc: 0.5651 - 575ms/epoch - 27ms/step
# Epoch 58/100
# 21/21 - 1s - c_loss: 0.7871 - c_acc: 0.6459 - r_acc: 0.4271 - p_loss: 1.6809 - p_acc: 0.5471 - val_p_loss: 0.8045 - val_p_acc: 0.5592 - 538ms/epoch - 26ms/step
# Epoch 59/100
# 21/21 - 1s - c_loss: 0.7750 - c_acc: 0.6165 - r_acc: 0.4208 - p_loss: 1.6540 - p_acc: 0.5198 - val_p_loss: 0.5967 - val_p_acc: 0.5444 - 516ms/epoch - 25ms/step
# Epoch 60/100
# 21/21 - 1s - c_loss: 1.1399 - c_acc: 0.6323 - r_acc: 0.4222 - p_loss: 1.6157 - p_acc: 0.5502 - val_p_loss: 0.6134 - val_p_acc: 0.5562 - 517ms/epoch - 25ms/step
# Epoch 61/100
# 21/21 - 1s - c_loss: 0.6805 - c_acc: 0.6444 - r_acc: 0.4256 - p_loss: 1.6557 - p_acc: 0.5502 - val_p_loss: 0.7105 - val_p_acc: 0.5858 - 518ms/epoch - 25ms/step
# Epoch 62/100
# 21/21 - 1s - c_loss: 0.7901 - c_acc: 0.6286 - r_acc: 0.4193 - p_loss: 1.6616 - p_acc: 0.5532 - val_p_loss: 0.5523 - val_p_acc: 0.5799 - 586ms/epoch - 28ms/step
# Epoch 63/100
# 21/21 - 1s - c_loss: 0.7108 - c_acc: 0.6414 - r_acc: 0.4196 - p_loss: 1.6417 - p_acc: 0.5593 - val_p_loss: 0.5407 - val_p_acc: 0.5740 - 536ms/epoch - 26ms/step
# Epoch 64/100
# 21/21 - 1s - c_loss: 0.5947 - c_acc: 0.6376 - r_acc: 0.4211 - p_loss: 1.6515 - p_acc: 0.5562 - val_p_loss: 0.6568 - val_p_acc: 0.5503 - 531ms/epoch - 25ms/step
# Epoch 65/100
# 21/21 - 1s - c_loss: 1.1649 - c_acc: 0.6436 - r_acc: 0.4163 - p_loss: 1.5598 - p_acc: 0.5502 - val_p_loss: 0.4596 - val_p_acc: 0.5680 - 514ms/epoch - 24ms/step
# Epoch 66/100
# 21/21 - 1s - c_loss: 0.7769 - c_acc: 0.6263 - r_acc: 0.4222 - p_loss: 1.6874 - p_acc: 0.5471 - val_p_loss: 0.4415 - val_p_acc: 0.5592 - 551ms/epoch - 26ms/step
# Epoch 67/100
# 21/21 - 1s - c_loss: 1.0404 - c_acc: 0.6143 - r_acc: 0.4204 - p_loss: 1.5691 - p_acc: 0.5441 - val_p_loss: 0.4685 - val_p_acc: 0.5503 - 572ms/epoch - 27ms/step
# Epoch 68/100
# 21/21 - 1s - c_loss: 0.9524 - c_acc: 0.6293 - r_acc: 0.4230 - p_loss: 1.5241 - p_acc: 0.5714 - val_p_loss: 0.4813 - val_p_acc: 0.5710 - 531ms/epoch - 25ms/step
# Epoch 69/100
# 21/21 - 1s - c_loss: 0.7576 - c_acc: 0.6526 - r_acc: 0.4230 - p_loss: 1.5999 - p_acc: 0.5593 - val_p_loss: 0.4504 - val_p_acc: 0.5740 - 535ms/epoch - 25ms/step
# Epoch 70/100
# 21/21 - 1s - c_loss: 0.8617 - c_acc: 0.6361 - r_acc: 0.4215 - p_loss: 1.5708 - p_acc: 0.5532 - val_p_loss: 0.3358 - val_p_acc: 0.5828 - 545ms/epoch - 26ms/step
# Epoch 71/100
# 21/21 - 1s - c_loss: 0.9602 - c_acc: 0.6376 - r_acc: 0.4211 - p_loss: 1.5388 - p_acc: 0.5623 - val_p_loss: 0.3687 - val_p_acc: 0.5503 - 534ms/epoch - 25ms/step
# Epoch 72/100
# 21/21 - 1s - c_loss: 0.7072 - c_acc: 0.6203 - r_acc: 0.4226 - p_loss: 1.7604 - p_acc: 0.5471 - val_p_loss: 0.3397 - val_p_acc: 0.5680 - 537ms/epoch - 26ms/step
# Epoch 73/100
# 21/21 - 1s - c_loss: 0.7305 - c_acc: 0.6526 - r_acc: 0.4204 - p_loss: 1.5497 - p_acc: 0.5532 - val_p_loss: 0.3576 - val_p_acc: 0.5710 - 534ms/epoch - 25ms/step
# Epoch 74/100
# 21/21 - 1s - c_loss: 1.0119 - c_acc: 0.6308 - r_acc: 0.4211 - p_loss: 1.5178 - p_acc: 0.5502 - val_p_loss: 0.3352 - val_p_acc: 0.5562 - 584ms/epoch - 28ms/step
# Epoch 75/100
# 21/21 - 1s - c_loss: 0.7418 - c_acc: 0.6368 - r_acc: 0.4215 - p_loss: 1.5243 - p_acc: 0.5897 - val_p_loss: 0.4432 - val_p_acc: 0.5828 - 549ms/epoch - 26ms/step
# Epoch 76/100
# 21/21 - 1s - c_loss: 0.8293 - c_acc: 0.6549 - r_acc: 0.4252 - p_loss: 1.4916 - p_acc: 0.5836 - val_p_loss: 0.3315 - val_p_acc: 0.5769 - 564ms/epoch - 27ms/step
# Epoch 77/100
# 21/21 - 1s - c_loss: 0.9799 - c_acc: 0.6534 - r_acc: 0.4196 - p_loss: 1.4482 - p_acc: 0.5593 - val_p_loss: 0.3881 - val_p_acc: 0.5592 - 524ms/epoch - 25ms/step
# Epoch 78/100
# 21/21 - 1s - c_loss: 0.7041 - c_acc: 0.6271 - r_acc: 0.4219 - p_loss: 1.5398 - p_acc: 0.5623 - val_p_loss: 0.2109 - val_p_acc: 0.5740 - 515ms/epoch - 25ms/step
# Epoch 79/100
# 21/21 - 1s - c_loss: 0.8921 - c_acc: 0.6466 - r_acc: 0.4260 - p_loss: 1.6481 - p_acc: 0.5866 - val_p_loss: 0.2252 - val_p_acc: 0.5917 - 516ms/epoch - 25ms/step
# Epoch 80/100
# 21/21 - 1s - c_loss: 0.8706 - c_acc: 0.6526 - r_acc: 0.4267 - p_loss: 1.4391 - p_acc: 0.5836 - val_p_loss: 0.2977 - val_p_acc: 0.5917 - 529ms/epoch - 25ms/step
# Epoch 81/100
# 21/21 - 1s - c_loss: 0.7574 - c_acc: 0.6602 - r_acc: 0.4215 - p_loss: 1.3444 - p_acc: 0.5836 - val_p_loss: 0.2453 - val_p_acc: 0.5740 - 545ms/epoch - 26ms/step
# Epoch 82/100
# 21/21 - 1s - c_loss: 1.2712 - c_acc: 0.6549 - r_acc: 0.4222 - p_loss: 1.7840 - p_acc: 0.5745 - val_p_loss: 0.3284 - val_p_acc: 0.5680 - 534ms/epoch - 25ms/step
# Epoch 83/100
# 21/21 - 1s - c_loss: 1.2281 - c_acc: 0.6429 - r_acc: 0.4163 - p_loss: 1.6502 - p_acc: 0.5866 - val_p_loss: 0.2918 - val_p_acc: 0.5828 - 522ms/epoch - 25ms/step
# Epoch 84/100
# 21/21 - 1s - c_loss: 1.1797 - c_acc: 0.6526 - r_acc: 0.4263 - p_loss: 1.4349 - p_acc: 0.5745 - val_p_loss: 0.2091 - val_p_acc: 0.5562 - 518ms/epoch - 25ms/step
# Epoch 85/100
# 21/21 - 1s - c_loss: 0.7970 - c_acc: 0.6594 - r_acc: 0.4312 - p_loss: 1.4814 - p_acc: 0.5927 - val_p_loss: 0.1881 - val_p_acc: 0.5947 - 552ms/epoch - 26ms/step
# Epoch 86/100
# 21/21 - 1s - c_loss: 0.9916 - c_acc: 0.6556 - r_acc: 0.4263 - p_loss: 1.4514 - p_acc: 0.5805 - val_p_loss: 0.2125 - val_p_acc: 0.5976 - 538ms/epoch - 26ms/step
# Epoch 87/100
# 21/21 - 1s - c_loss: 1.1621 - c_acc: 0.6466 - r_acc: 0.4263 - p_loss: 1.3478 - p_acc: 0.5745 - val_p_loss: 0.2175 - val_p_acc: 0.5740 - 577ms/epoch - 27ms/step
# Epoch 88/100
# 21/21 - 1s - c_loss: 0.9935 - c_acc: 0.6669 - r_acc: 0.4301 - p_loss: 1.4566 - p_acc: 0.5988 - val_p_loss: 0.2493 - val_p_acc: 0.5888 - 534ms/epoch - 25ms/step
# Epoch 89/100
# 21/21 - 1s - c_loss: 0.9823 - c_acc: 0.6662 - r_acc: 0.4330 - p_loss: 1.4060 - p_acc: 0.5897 - val_p_loss: 0.2206 - val_p_acc: 0.5740 - 530ms/epoch - 25ms/step
# Epoch 90/100
# 21/21 - 1s - c_loss: 0.8171 - c_acc: 0.6474 - r_acc: 0.4278 - p_loss: 1.5198 - p_acc: 0.5988 - val_p_loss: 0.1703 - val_p_acc: 0.6213 - 558ms/epoch - 27ms/step
# Epoch 91/100
# 21/21 - 1s - c_loss: 0.6409 - c_acc: 0.6714 - r_acc: 0.4427 - p_loss: 1.4413 - p_acc: 0.6231 - val_p_loss: 0.2132 - val_p_acc: 0.6272 - 506ms/epoch - 24ms/step
# Epoch 92/100
# 21/21 - 1s - c_loss: 1.1314 - c_acc: 0.6722 - r_acc: 0.4338 - p_loss: 1.3652 - p_acc: 0.5988 - val_p_loss: 0.1432 - val_p_acc: 0.6361 - 517ms/epoch - 25ms/step
# Epoch 93/100
# 21/21 - 1s - c_loss: 1.0642 - c_acc: 0.6519 - r_acc: 0.4360 - p_loss: 1.2577 - p_acc: 0.6079 - val_p_loss: 0.1699 - val_p_acc: 0.5562 - 533ms/epoch - 25ms/step
# Epoch 94/100
# 21/21 - 1s - c_loss: 0.8268 - c_acc: 0.6684 - r_acc: 0.4282 - p_loss: 1.3088 - p_acc: 0.6049 - val_p_loss: 0.1389 - val_p_acc: 0.5503 - 568ms/epoch - 27ms/step
# Epoch 95/100
# 21/21 - 1s - c_loss: 0.9452 - c_acc: 0.6639 - r_acc: 0.4323 - p_loss: 1.3318 - p_acc: 0.6049 - val_p_loss: 0.2319 - val_p_acc: 0.6183 - 547ms/epoch - 26ms/step
# Epoch 96/100
# 21/21 - 1s - c_loss: 0.9066 - c_acc: 0.6624 - r_acc: 0.4330 - p_loss: 1.3203 - p_acc: 0.6261 - val_p_loss: 0.1107 - val_p_acc: 0.6154 - 517ms/epoch - 25ms/step
# Epoch 97/100
# 21/21 - 1s - c_loss: 1.0805 - c_acc: 0.6496 - r_acc: 0.4271 - p_loss: 1.2364 - p_acc: 0.5805 - val_p_loss: 0.0831 - val_p_acc: 0.6361 - 533ms/epoch - 25ms/step
# Epoch 98/100
# 21/21 - 1s - c_loss: 0.6919 - c_acc: 0.6481 - r_acc: 0.4315 - p_loss: 1.3155 - p_acc: 0.6383 - val_p_loss: 0.1064 - val_p_acc: 0.6006 - 517ms/epoch - 25ms/step
# Epoch 99/100
# 21/21 - 1s - c_loss: 0.8837 - c_acc: 0.6556 - r_acc: 0.4353 - p_loss: 1.3197 - p_acc: 0.6109 - val_p_loss: 0.1200 - val_p_acc: 0.6183 - 543ms/epoch - 26ms/step
# Epoch 100/100
# 21/21 - 1s - c_loss: 0.7627 - c_acc: 0.6586 - r_acc: 0.4330 - p_loss: 1.4629 - p_acc: 0.6261 - val_p_loss: 0.0974 - val_p_acc: 0.6331 - 582ms/epoch - 28ms/step

# %% [markdown]
# ### Plot the training loss and accuracy
#
# *Contrastive accuracy*: self-supervised metric, the ratio of cases in which the representation of an image is more similar to its differently augmented version's one, than to the representation of any other image in the current batch.
#
# *Correlation accuracy*: self-supervised metric, the ratio of cases in which the representation of an image is more similar to its differently augmented version's one, than to the representation of any other image in the queue.
#
# *Probe accuracy*: supervised metric, the ratio of cases in which the representation of an image is more similar to its label's one, than to the representation of any other label.

# %%
print(pretrain_history.history.keys())
# Out:
# dict_keys(['c_loss', 'c_acc', 'r_acc', 'p_loss', 'p_acc', 'val_p_loss', 'val_p_acc'])

# %%
# summarize history for loss
plt.figure(figsize=(15, 10))
# plt.plot(pretrain_history.history['c_loss'])
plt.plot(pretrain_history.history['p_loss'])
plt.plot(pretrain_history.history['val_p_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['probe_loss', 'validation_prob_loss'], loc='upper right')
plt.show()

# %%
# summarize history for accuracy
plt.figure(figsize=(15, 10))
plt.plot(pretrain_history.history['c_acc'])
plt.plot(pretrain_history.history['r_acc'])
plt.plot(pretrain_history.history['p_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['contrastive_accuracy', 'correlation_accuracy', 'probe_accuracy'], loc='upper left')
plt.show()

# %% [markdown]
# ## Plot the learned representations using UMAP
#
# Plot the representations of the labeled data in the representation space learned by the NNCLR encoder. Use UMAP to reduce the dimensionality to 2. The color of each point corresponds to its label.

# %%
import matplotlib.pyplot as plt
plt.rc('font', size=12)          # controls default text sizes
plt.rc('axes', titlesize=16)     # fontsize of the axes title
plt.rc('axes', labelsize=12)    # fontsize of the x and y labels
plt.rc('legend', fontsize=12)    # legend fontsize
plt.rc('figure', titlesize=16)  # fontsize of the figure title

# %%
# Plot the representations of the unlabeled data in the representation space learned by the NNCLR encoder. Use UMAP to reduce the dimensionality to 2. The color of each point corresponds to its label.

import umap.umap_ as umap
import numpy as np

# Get the representations of the unlabeled data.
unlabeled_feature_vectors = model.encoder(x_train, training=False)

# Reduce the dimensionality of the representations to 2.
reducer = umap.UMAP()
umap_embeddings = reducer.fit_transform(unlabeled_feature_vectors)

# Plot the representations.
plt.figure(figsize=(12, 10))
plt.scatter(umap_embeddings[:, 0], umap_embeddings[:, 1], c=y_train, s=5.0, cmap='Spectral')
# plt.gca().set_aspect('equal', 'datalim')
plt.colorbar(boundaries=np.arange(7)-0.5).set_ticks(np.arange(6))
plt.title('UMAP projection of the representations of the unlabeled data')
# Out:
# Text(0.5, 1.0, 'UMAP projection of the representations of the unlabeled data')

# %%
# Plot the representations of the labeled data in the representation space learned by the NNCLR encoder. Use UMAP to reduce the dimensionality to 2.

# Get the representations of the labeled data.
labeled_feature_vectors = model.encoder(x_validate, training=False)

# Reduce the dimensionality of the representations to 2.
# reducer = umap.UMAP()
# umap_embeddings = reducer.fit_transform(labeled_feature_vectors)
umap_embeddings = reducer.transform(labeled_feature_vectors)

# Plot the representations.
plt.figure(figsize=(12, 10))
plt.scatter(umap_embeddings[:, 0], umap_embeddings[:, 1], c=y_validate, s=5.0, cmap='Spectral')
# plt.gca().set_aspect('equal', 'datalim')
plt.colorbar(boundaries=np.arange(7)-0.5).set_ticks(np.arange(6))
plt.title('UMAP projection of the representations of the labeled data')
# Out:
# Text(0.5, 1.0, 'UMAP projection of the representations of the labeled data')

# %%
# Plot the representations of the test data in the representation space learned by the NNCLR encoder. Use UMAP to reduce the dimensionality to 2. The color of each point corresponds to its label.

# Get the representations of the test data.
test_feature_vectors = model.encoder(x_test, training=False)

# Reduce the dimensionality of the representations to 2.
# reducer = umap.UMAP()
# umap_embeddings = reducer.fit_transform(test_feature_vectors)
umap_embeddings = reducer.transform(test_feature_vectors)

# Plot the representations.
plt.figure(figsize=(12, 10))
plt.scatter(umap_embeddings[:, 0], umap_embeddings[:, 1], c=y_test, s=5.0, cmap='Spectral')
# plt.gca().set_aspect('equal', 'datalim')
plt.colorbar(boundaries=np.arange(7)-0.5).set_ticks(np.arange(6))
plt.title('UMAP projection of the representations of the test data')
# Out:
# Text(0.5, 1.0, 'UMAP projection of the representations of the test data')

# %% [markdown]
# ## Fine tune the model
#
# Fine tune the NNCLR encoder on the labeled data. The classifier is trained on the labeled data.

# %%
finetuning_model = keras.Sequential(
    [
        layers.Input(shape=input_shape),
        augmenter("classification_augmenter", input_shape=input_shape),
        model.encoder,
        layers.Dense(n_classes),
    ],
    name="finetuning_model",
)
finetuning_model.compile(
    optimizer=keras.optimizers.Adam(),
    loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=[keras.metrics.SparseCategoricalAccuracy(name="acc")],
    run_eagerly=None # True = run eagerly, False = run as graph, None = autodetect
)

finetuning_history = finetuning_model.fit(
    labeled_train_dataset, epochs=finetune_num_epochs, validation_data=test_dataset
)
# Out:
# Epoch 1/100
# 21/21 [==============================] - 2s 33ms/step - loss:
100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.2629 - acc: 0.8723 - val_loss: 0.4113 - val_acc: 0.8550
# Epoch 98/100
# 21/21 [==============================] - 0s 12ms/step - loss: 0.2602 - acc: 0.8906 - val_loss: 0.3041 - val_acc: 0.9172
# Epoch 99/100
# 21/21 [==============================] - 0s 12ms/step - loss: 0.2368 - acc: 0.9058 - val_loss: 0.5449 - val_acc: 0.7988
# Epoch 100/100
# 21/21 [==============================] - 0s 13ms/step - loss: 0.3092 - acc: 0.8723 - val_loss: 0.6726 - val_acc: 0.7278

# %% [markdown]
# ### Plot the fine-tuning loss and accuracy

# %%
# summarize history for loss

plt.plot(finetuning_history.history['loss'])
plt.plot(finetuning_history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train_loss', 'test_loss'], loc='upper right')
plt.show()

# %%
# summarize history for accuracy
plt.plot(finetuning_history.history['acc'])
plt.plot(finetuning_history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train_accuracy', 'test_accuracy'], loc='upper left')
plt.show()

# %% [markdown]
# ## Evaluate our fine tuned model on the test set

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
import pandas as pd
import seaborn as sns
import numpy as np

#### Show results
predictions = finetuning_model.predict(test_dataset, verbose=0, batch_size=32)
#must use values not one-hot encoding, use argmax to convert
y_pred = np.argmax(predictions, axis=-1) # axis=-1 means last axis
y_test = np.concatenate([y for x, y in test_dataset], axis=0)
print('Prediction accuracy: {0:.3f}'.format(accuracy_score(y_test, y_pred)))

print(classification_report(y_test, y_pred, target_names=t_names))
cm = confusion_matrix(y_test, y_pred)
print(cm)
cm_df = pd.DataFrame(cm,
                     index = t_names, 
                     columns = t_names)
fig = plt.figure(figsize=(6.5,5))
sns.heatmap(cm_df, annot=True, fmt='d', cmap='cubehelix_r')
plt.title('1D CNN using e4_Nov2019'+'\nAccuracy:{0:.3f}'.format(accuracy_score(y_test, y_pred)))
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.tight_layout() # keeps labels from being cutoff when saving as pdf
plt.show()
# Out:
# Prediction accuracy: 0.743
#               precision    recall  f1-score   support
#
#   Downstairs       0.39      0.92      0.55        49
#      Jogging       0.90      0.98      0.94        58
#      Sitting       1.00      0.90      0.95        61
#     Standing       0.92      1.00      0.96        58
#     Upstairs       1.00      0.04      0.07        52
#      Walking       0.87      0.57      0.69        60
#
#     accuracy                           0.74       338
#    macro avg       0.85      0.73      0.69       338
# weighted avg       0.86      0.74      0.71       338
#
# [[45  4  0  0  0  0]
#  [ 0 57  0  0  0  1]
#  [ 0  1 55  5  0  0]
#  [ 0  0  0 58  0  0]
#  [46  0  0  0  2  4]
#  [25  1  0  0  0 34]]

# %% [markdown]
# ## Evaluate the learned representations using a KNN classifier

# %%
from sklearn.neighbors import KNeighborsClassifier

# Convert train dataset to feature vectors using the self-supervised encoder
train_feature_vectors = model.encoder(x_train, training=False)

knn = KNeighborsClassifier(n_neighbors=3)
knn_model = knn.fit(train_feature_vectors, y_train)

# Predict test set with the knn model
test_feature_vectors = model.encoder(x_test, training=False)
y_pred = knn_model.predict(test_feature_vectors)

print('Prediction accuracy: {0:.3f}'.format(accuracy_score(y_test, y_pred)))
print(classification_report(y_test, y_pred, target_names=t_names))
cm = confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# Prediction accuracy: 0.932
#               precision    recall  f1-score   support
#
#   Downstairs       0.91      0.84      0.87        49
#      Jogging       1.00      0.95      0.97        58
#      Sitting       0.98      1.00      0.99        61
#     Standing       1.00      0.97      0.98        58
#     Upstairs       0.81      0.85      0.83        52
#      Walking       0.88      0.97      0.92        60
#
#     accuracy                           0.93       338
#    macro avg       0.93      0.93      0.93       338
# weighted avg       0.93      0.93      0.93       338
#
# [[41  0  0  0  7  1]
#  [ 1 55  0  0  1  1]
#  [ 0  0 61  0  0  0]
#  [ 1  0  1 56  0  0]
#  [ 2  0  0  0 44  6]
#  [ 0  0  0  0  2 58]]
